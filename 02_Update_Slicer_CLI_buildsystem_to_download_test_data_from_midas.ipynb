# %%
import hashlib
import os
import re
import shutil

# %reload_ext autoreload
# %autoreload 1
# %aimport pydas

#---------------------------------------------------------------------------
slicer_src = '/home/jcfr/Projects/Slicer'
cli_src_directory = os.path.join(slicer_src, 'Modules/CLI')

# The goal is to remove this global directory and have every modules and libraries
# listing their own requirements regarding input test and baseline data.
global_test_data_dir = '/home/jcfr/Projects/Slicer/Testing/Data/Input'
global_mrml_test_data_dir = '/home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData'
global_datafiles_candidate_for_removal = []

# Folder id associated Slicer data hosted on http://slicer.kitware.com/midas3
midas_data_folder_id = 301

midas_url = 'http://slicer.kitware.com/midas3'
email = os.environ["MIDAS_PACKAGE_EMAIL"]
apikey = os.environ["MIDAS_PACKAGE_API_KEY"]

# Update sys.path adding Slicer python module directory
slicer_python_dir = os.path.join(slicer_src, 'Base/Python/slicer/release')
import sys
if slicer_python_dir not in sys.path:
    sys.path.append(slicer_python_dir)

import midasdata

# If enabled, update midas creating missing folder and uploading data if needed.
midas_update = True

# If enabled, generate .md5 files for each data files, rename the original
# data file with extension '.bkp'
# If false, revert the previous step using .bkp files (if any)
convert_to_md5 = True
delete_bkp = True

# If enabled, this option will connect to the midas server and check
# if the current CLI test data have been uploaded.
check_data_is_uploaded = False

# Disable replacement of 'add_test' with 'ExternalData_add_target'
replace_add_test = True

# List of data files to exclude
filenames_to_exclude = ['Brain_slice.nrrd']

# List of data file extensions that should NOT be considered
extensions_to_exclude = ['.tfm', '.txt', '.md5', '.bkp']

#---------------------------------------------------------------------------
# Initialize global vars

communicator = pydas.core.Communicator(midas_url)
def token(email, apikey):
    return communicator.login_with_api_key(email, apikey)

midas_data_folders = communicator.folder_children(token(email, apikey), midas_data_folder_id)

modulesIndex = midasdata._getFolderIndex(midas_data_folders, "Modules")
modulesID = midasdata._getIDfromIndex(midas_data_folders, "folder", modulesIndex)
availableModules = communicator.folder_children(token(email, apikey), modulesID)
availableModulesFolders = availableModules["folders"]

moduleNames = []

MODULE_INPUT_SUBDIR = 'Data/Input'
MODULE_BASELINE_SUBDIR = 'Data/Baseline'

#---------------------------------------------------------------------------
def get_module_data_directories(cli_src_directory):
    data_directories = []
    for root, dirnames, filenames in os.walk(cli_src_directory):
        if root.endswith(MODULE_INPUT_SUBDIR):
            data_directories.append(root)
        if root.endswith(MODULE_BASELINE_SUBDIR):
            data_directories.append(root)
    return sorted(data_directories)

#---------------------------------------------------------------------------
def check_module_test_data_are_uploaded(cli_src_directory):

    # Collect data directories
    data_directories = get_module_data_directories(cli_src_directory)
    for data_directory in data_directories:

        moduleName = root.split('/')[-3]
        # Skip 'ExtractSkeleton' because it has already been updated
        #if moduleName == 'ExtractSkeleton':
        #    continue

        # Check if existing data file have been uploaded on Midas
        for filename in os.listdir(data_directory):
            filename = os.path.join(data_directory, filename)
            if filename.endswith('.md5'):
                continue
            digest = md5(os.path.join(root, filename))
            print("[%s] %s => %s [uploaded: %s]" % (moduleName, filename, digest, has_bitstream(filename, digest)))

#---------------------------------------------------------------------------
def add_external_data_target(cmakelist):
    # Should the footer be appended ?
    footer_already_appended = False
    # Should a line be added between end of files and footer ?
    lastline_empty = False
    with open(cmakelist, 'r') as myfile:
        lines = myfile.readlines()
        footer_already_appended = 'ExternalData_add_target' in "".join(lines)
        if lines[-1] == "\n":
            lastline_empty = True
    # Append footer
    if not footer_already_appended:
        with open(cmakelist, "a") as myfile:
            if not lastline_empty:
                myfile.write("\n")
            myfile.write("""#-----------------------------------------------------------------------------
ExternalData_add_target(${CLP}Data)
set_target_properties(${CLP}Data PROPERTIES FOLDER ${${CLP}_TARGETS_FOLDER})
""")
        print("=> [footer ok] (lastline_empty: %s)" % (lastline_empty))
    else:
        print("=> [footer skip] (already appended)")

#---------------------------------------------------------------------------
def has_line(cmakelist, regex):
    p = re.compile(regex)
    with open(cmakelist, 'r') as myfile:
        for line in myfile.readlines():
            if p.match(line):
                return True
    return False
    
#---------------------------------------------------------------------------
def remove_matching_lines(cmakelist, regex):
    p = re.compile(regex)
    updated_lines = []
    removed = 0
    with open(cmakelist, 'r') as myfile:
        lines = myfile.readlines()
        for line in lines:
            if not p.match(line):
                updated_lines.append(line)
            else:
                removed = removed + 1
    with open(cmakelist, "w") as myfile:
        myfile.writelines(updated_lines)
    return removed > 0

#---------------------------------------------------------------------------
def add_line_after(cmakelist, regex, line_to_add):
    p = re.compile(regex)
    updated_lines = []
    added = 0
    with open(cmakelist, 'r') as myfile:
        lines = myfile.readlines()
        for line in lines:
            updated_lines.append(line)
            if p.match(line):
                updated_lines.append(line_to_add + '\n')
                added = added + 1
    if not added <= 1:
        raise Exception("File '%s' is expected to have only one line matching '%s'" % (cmakelist, regex))
    with open(cmakelist, "w") as myfile:
        myfile.writelines(updated_lines)
    return added > 0

#---------------------------------------------------------------------------
# Datafile helper functions

#---------------------------------------------------------------------------
def md5(fname):
    hash = hashlib.md5()
    with open(fname) as f:
        for chunk in iter(lambda: f.read(4096), ""):
            hash.update(chunk)
    return hash.hexdigest()

#---------------------------------------------------------------------------
def datafile_regex(varname):
    return ur'\s(\${' + varname + ur'}\/[\${}\w\-\_]+\.[\w\d]+(\.[\w\d]+)?)'

#---------------------------------------------------------------------------
def relocate_test_data(line, varname, global_test_data_dir, module_input_dir):
    if "${%s}" % varname not in line:
        return line
    p = re.compile(datafile_regex(varname))
    m = re.search(p, line)
    if m:
        g = m.group(1)
        data_filepath = g
                        
        data_filepath = data_filepath.replace("${%s}" % varname, global_test_data_dir)
        data_filename = os.path.basename(data_filepath)
        dest_data_filepath = os.path.join(module_input_dir, data_filename)
        if os.path.isfile(data_filepath):
            print("\n=> [data_filepath] %s" % data_filepath)
            print("=> [dest_data_filepath] %s" % dest_data_filepath)
            print("=> [global_test_data_dir -> module_input_dir] %s" % data_filename)
            dest_data_path = os.path.dirname(dest_data_filepath)
            if not os.path.exists(dest_data_path):
                print("=> %s [created]" % dest_data_path)
                os.makedirs(dest_data_path)
            shutil.copy(data_filepath, dest_data_filepath)
            for data_dependency_filepath in datafile_dependencies(data_filepath):
                shutil.copy(data_dependency_filepath, dest_data_path)
                print("=> %s [copied]" % os.path.basename(data_dependency_filepath))

            if moduleName not in missing_midas_module_input_data:
                missing_midas_module_input_data[moduleName] = []

            missing_midas_module_input_data[moduleName].append(dest_data_filepath)
            if data_filepath not in global_datafiles_candidate_for_removal:
                global_datafiles_candidate_for_removal.append(data_filepath)
        return line.replace("${%s}" % varname, '${INPUT}')
    else:
        return line

#---------------------------------------------------------------------------
def datafile_dependency_is_gz(filename):
    with open(filename, "r") as _file:
        return '.gz' in "".join(_file.readlines())

#---------------------------------------------------------------------------
def datafile_is_serie(data_filepath):
    base_dir = os.path.dirname(data_filepath)
    data_filename = os.path.basename(data_filepath)
    (basename, ext) = os.path.splitext(data_filename)
    # This implementation simply check if file '<basename>.1.<ext>' exists
    # For a complete implementation see "ExternalData_arg_series()" in
    # ExternalData CMake module.
    serie_item = os.path.join(base_dir, basename + '.1' + ext)
    return os.path.isfile(serie_item)

#---------------------------------------------------------------------------
def datafile_dependencies(data_filepath):
    dependencies = []
    (basename, ext) = os.path.splitext(data_filepath)
    if ext == '.nhdr':
        if datafile_dependency_is_gz(data_filepath):
            return [basename + '.raw.gz']
        else:
            return [basename + '.raw']
    elif ext == '.hdr':
        return [basename + '.img']
    
    # XXX Add support for file series
    
    return dependencies
        

#---------------------------------------------------------------------------
# Map associating module folder that should be created on Midas + data file that should be uploaded
missing_midas_module_input_data = {}

#---------------------------------------------------------------------------
print("\n" + ("*" * 80) + "\nLocal: Process CMakeLists.txt\n" + ("*" * 80))

for root, dirnames, filenames in os.walk(cli_src_directory):
    
    if not root.endswith('/Testing'):
        continue
        
    testing_dir = root

    cmakelist = os.path.join(testing_dir, 'CMakeLists.txt')
    
    if not os.path.exists(cmakelist):
        continue
    
    testing_dir = os.path.dirname(cmakelist)
    
    # Get moduleName
    moduleName = os.path.basename(os.path.dirname(testing_dir))
    
    if moduleName not in moduleNames:
        moduleNames.append(moduleName)
    
    print("\n%s" % (cmakelist.replace(cli_src_directory + '/', '')))
    
    add_external_data_target(cmakelist)
    
    tmp_cmakelist = cmakelist + ".tmp"

    with open(tmp_cmakelist, "w") as fout:
        
        # Get baseline_dir/input_dir assuming all CLIs are organized similarly.
        baseline_dir = os.path.join(testing_dir, '..', MODULE_BASELINE_SUBDIR)
        if not os.path.isdir(baseline_dir):
            baseline_dir = None
        input_dir = os.path.join(testing_dir, '..', MODULE_INPUT_SUBDIR)
        
        with open(cmakelist, "r") as fin:
            for line in fin:
                
                if replace_add_test:
                    pos = line.find('add_test(')
                    if pos >= 0 and 'ExternalData_add_test' not in line:
                        #print("pos:", pos, line[0:pos])
                        line = line.replace('add_test(', 'ExternalData_add_test(${CLP}Data\n' + line[0:pos] + '  ')
                
                # Identify all test data that should be copied into the module Baseline or Input directory
                line = relocate_test_data(line, 'TEST_DATA', global_test_data_dir, input_dir)
                line = relocate_test_data(line, 'MRML_TEST_DATA', global_mrml_test_data_dir, input_dir)

                # Add 'DATA{}' where it applies.
                for varname in ['BASELINE', 'INPUT']:
                    # For example, it will:
                    #  - looks for line containing "${BASELINE}"
                    #  - extract the associated path: ${BASELINE}/path/to/foo.nrrd
                    #  - replace it with DATA{${BASELINE}/path/to/foo.nrrd} if not already done
                    #  - this can be skipped by adding '.nrrd' to 'extensions_to_exclude'
                    if "${%s}" % varname in line:
                        p = re.compile(datafile_regex(varname))
                        m = re.search(p, line)
                        if m:
                            g = m.group(1)
                            filename = os.path.basename(g)
                            if not os.path.basename(filename) in filenames_to_exclude \
                                and not os.path.splitext(filename)[1] in extensions_to_exclude:
                                line = line.replace(g, 'DATA{' + g + '}')
                            else:
                                print("=> skipping addition of DATA{}: %s" % m.group(0))

                # Update DATA association.
                #  - .nhdr will be associated with either '.raw' or '.raw.gz'
                #  - .hdr will be associated with '.img'
                if 'DATA{' in line:
                    p = re.compile(ur'DATA{([{}\w\_\-\/\$\.,]*)}')
                    m = re.search(p, line)
                    for g in m.groups():

                        if g.endswith('.nhdr'):
                            data_filepath = g
                            data_filepath = data_filepath.replace('${CLP}', moduleName)
                            if baseline_dir:
                                data_filepath = data_filepath.replace('${BASELINE}', baseline_dir)
                            data_filepath = data_filepath.replace('${INPUT}', input_dir)
                            data_basename = os.path.splitext(os.path.basename(data_filepath))[0]
                            try:
                                # Append .raw
                                updated = g + ',' + data_basename + '.raw'
                                if datafile_dependency_is_gz(data_filepath):
                                    updated = updated + '.gz'
                                #print("...... %s => %s" % (g, updated))
                                line = line.replace(g, updated)
                                print("=> [data_association] (%s)" % (updated))
                            except IOError as e:
                                print("=> [data_association] %s" % (e))
                        if g.endswith('.raw'):
                            # Fix incorrect association. Associate nhdr with '.raw.gz'
                            # instead of '.raw' if it applies.
                            data_filepath = g.split(',')[0]
                            data_filepath = data_filepath.replace('${CLP}', moduleName)
                            if baseline_dir:
                                data_filepath = data_filepath.replace('${BASELINE}', baseline_dir)
                            data_filepath = data_filepath.replace('${INPUT}', input_dir)
                            if os.path.isfile(data_filepath) and datafile_dependency_is_gz(data_filepath):
                                updated = os.path.basename(g) + '.gz'
                                line = line.replace(g, updated)
                                print("=> [data_association] (%s)" % (updated))
                        if g.endswith('.hdr'):
                            data_filename = os.path.basename(g)
                            base = os.path.splitext(data_filename)[0]
                            # Append .img
                            updated = g + ',' + base + '.img'
                            #print("...... %s => %s" % (g, updated))
                            line = line.replace(g, updated)
                            print("=> [data_association] (%s)" % (updated))
                        
                        # Check if data file is associated with a series
                        data_filename = g.replace('${CLP}', moduleName)
                        if baseline_dir:
                            data_filename = data_filename.replace('${BASELINE}', baseline_dir)
                        if input_dir:
                            data_filename = data_filename.replace('${INPUT}', input_dir)
                        # Check if the file belong to a serie
                        if datafile_is_serie(data_filename):
                            updated = g + ',:'
                            line = line.replace(g, updated)
                            print("=> [data_association] (%s)" % (updated))
                            
                fout.write(line)
    
    # Remove `set(TEST_DATA ...` line
    remove_matching_lines(tmp_cmakelist, ur'^set\(TEST_DATA .+\)$')
    remove_matching_lines(tmp_cmakelist, ur'^set\(MRML_TEST_DATA .+\)$')

    # Add `set(INPUT ...)` line after the `set(BASELINE ...)` if it
    # exists, otherwise after `set(CLP ...)`
    if has_line(tmp_cmakelist, ur'^set\(BASELINE .+\)$'):
        add_line_after(tmp_cmakelist, ur'^set\(BASELINE .+\)$', 'set(INPUT ${CMAKE_CURRENT_SOURCE_DIR}/../Data/Input)')
    else:
        add_line_after(tmp_cmakelist, ur'^set\(CLP .+\)$', 'set(INPUT ${CMAKE_CURRENT_SOURCE_DIR}/../Data/Input)')
    
    shutil.move(cmakelist + ".tmp", cmakelist)
    #break


#---------------------------------------------------------------------------
# Pydas helper functions

#---------------------------------------------------------------------------
def has_bitstream(name, checksum):
    items = communicator.search_item_by_name(filename)
    for item in items:
        item_id = item['item_id']
        item_data = communicator.item_get(token(email, apikey), item_id)
        if len(item_data['revisions']) > 0:
            if item_data['revisions'][-1]['bitstreams'][0]['checksum'] == checksum:
                return True
    return False

#---------------------------------------------------------------------------
def folder_children(folder_id, children_type="folder"):
    folders = communicator.folder_children(token(email, apikey), folder_id)
    return {folder['name']: folder[children_type + '_id'] for folder in folders[children_type + 's']}

#---------------------------------------------------------------------------
def get_or_create_module_test_data_directory(module_name, test_data_type):
    # Get <module_name> folder id, or create it if needed
    try:
        module_folder_id = midas_module_names[module_name]
        #print("=> %s [Found module_folder_id: %s]" % (module_name, module_folder_id))
    except KeyError:
        module_folder = communicator.create_folder(token(email, apikey), module_name, modules_folder_id)
        module_folder_id = module_folder['folder_id']
        #print("=> %s [Created module_folder_id: %s]" % (module_name, module_folder_id))

    # Get Nightly folder id, or create it if needed
    versions = folder_children(module_folder_id)
    try:
        nightly_folder_id = versions['Nightly']
        #print("=> %s [Found nightly_folder_id: %s]" % (module_name, nightly_folder_id))
    except KeyError:
        nightly_folder = communicator.create_folder(token(email, apikey), 'Nightly', module_folder_id)
        nightly_folder_id = nightly_folder['folder_id']
        #print("=> %s [Created nightly_folder_id: %s]" % (module_name, nightly_folder_id))

    # Get Testing folder id, or create it if needed
    testings = folder_children(nightly_folder_id)
    try:
        testing_folder_id = testings['Testing']
        #print("=> %s [Found testing_folder_id: %s]" % (module_name, testing_folder_id))
    except KeyError:
        testing_folder = communicator.create_folder(token(email, apikey), 'Testing', nightly_folder_id)
        testing_folder_id = testing_folder['folder_id']
        #print("=> %s [Created testing_folder_id: %s]" % (module_name, testing_folder_id))

    # Get testdata_type (Input or Baseline) folder id, or create it if needed
    testdata_types = folder_children(testing_folder_id)
    try:
        test_data_type_folder_id = testdata_types[test_data_type]
        #print("=> %s [Found test_data_type_folder_id: %s / %s]" % (module_name, test_data_type_folder_id, test_data_type))
    except KeyError:
        test_data_type_folder = communicator.create_folder(token(email, apikey), test_data_type, testing_folder_id)
        test_data_type_folder_id = test_data_type_folder['folder_id']
        #print("=> %s [Created test_data_type_folder_id: %s / %s]" % (module_name, test_data_type_folder_id, test_data_type))
    return test_data_type_folder_id

#---------------------------------------------------------------------------
def upload_revision(item_id, filepath):
    checksum = md5(filepath)
    filename = os.path.basename(filepath)
    print("=> md5(%s): %s" % (filename, checksum))
    upload_token = communicator.generate_upload_token(token(email, apikey), item_id, filename, checksum=checksum, create_additional_revision=True)
    if upload_token:
        communicator.perform_upload(upload_token, filename, item_id=item_id, filepath=filepath, create_additional_revision=True)
    else:
        print("=> adding reference to existing bitstream")
    print("Done")

#---------------------------------------------------------------------------
def upload_item(folder_id, filepath):
    filename = os.path.basename(filepath)
    # Get existing item if one exists with the same name
    item_names = folder_children(folder_id, children_type='item')
    try:
        item_id = item_names[filename]
        print("=> found item: %s" % (item_id))
    except KeyError:
        item = communicator.create_item(token(email, apikey), filename, folder_id)
        item_id = item['item_id']
        print("=> item created: %s" % (item_id))
    
    upload_revision(item_id, filepath)

#---------------------------------------------------------------------------
# Create module directory in midas if needed, and upload data    

modules_folder_id = 310

if midas_update:
    midas_module_names = folder_children(modules_folder_id)

    print("\n" + ("*" * 80) + "\nMidas: Create module directories and upload missing input test data\n" + ("*" * 80))
    for module_name in missing_midas_module_input_data:
        test_data_folder_id = get_or_create_module_test_data_directory(module_name, 'Input')
        # Upload test data
        print("%s [folder_id:%s]" % (module_name, test_data_folder_id))
        for data_filepath in missing_midas_module_input_data[module_name]:
            print("%s uploading %s" % (module_name, data_filepath))
            upload_item(test_data_folder_id, data_filepath)

#---------------------------------------------------------------------------
# File that could potentially be removed from the <global_test_data_dir>

print("\n" + ("*" * 80) + "\nMidas: Potential candidate for removal\n" + ("*" * 80))

# get all list contains in the map, flatten the list, remove duplicates
#_list = [v for (k, v) in missing_midas_module_input_data.iteritems()]
#global_datafiles_candidate_for_removal = list(set(itertools.chain.from_iterable(_list)))
for datafile in global_datafiles_candidate_for_removal:
    print(datafile)


#---------------------------------------------------------------------------
print("\n" + ("*" * 80) + "\nLocal: Convert data file to md5 if it applies\n" + ("*" * 80))
# Convert data file to md5 if it applies
for data_directory in get_module_data_directories(cli_src_directory):
    for filename in os.listdir(data_directory):
        filepath = os.path.join(data_directory, filename)
        basename = os.path.basename(filename)
    
        print("\n%s" % filename)

        if basename in filenames_to_exclude:
            print("\n%s skipping" % filename)
            continue

        if convert_to_md5:
            if os.path.splitext(filepath)[1] not in extensions_to_exclude:
                checksum = md5(filepath)
                with open(filepath + ".md5", "w") as myfile:
                    myfile.write(checksum + "\n")
                print("=> %s.md5 [done]" % basename)
                shutil.move(filepath, filepath + '.bkp')
                print("=> %s.bkp [done]" % basename)
                filepath = filepath + '.bkp'
                basename = os.path.basename(filename)
            
            if delete_bkp and filepath.endswith('.bkp'):
                os.remove(filepath)
                print("=> %s [removed]" % basename)
                
            print("=> [ok]")
        elif os.path.splitext(filepath)[1] == '.bkp':
            original_filename = filepath.replace('.bkp', '')
            shutil.move(filepath, original_filename)
            print("=> %s [restored]" % original_filename)
            print("\n%s restoring" % original_filename)
        else:
            print("=> [nothing-to-do]")


#---------------------------------------------------------------------------
if check_data_is_uploaded:
    check_module_test_data_are_uploaded(cli_src_directory)
            

# Display command allowing to run associated tests
print("\n")
for moduleName in moduleNames:
    print("ctest -R %s" % moduleName)
# Out:
# ********************************************************************************
# Local: Process CMakeLists.txt
# ********************************************************************************
#
# ProbeVolumeWithModel/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# SimpleRegionGrowingSegmentation/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/${CLP}Test.nhdr,SimpleRegionGrowingSegmentationTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/SimpleRegionGrowingSegmentation/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/SimpleRegionGrowingSegmentation/Testing/../Data/Input [created]
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# DiffusionWeightedVolumeMasking/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helix-DWI.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionWeightedVolumeMasking/Testing/../Data/Input/helix-DWI.nhdr
# => [global_test_data_dir -> module_input_dir] helix-DWI.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionWeightedVolumeMasking/Testing/../Data/Input [created]
# => helix-DWI.raw.gz [copied]
# => [data_association] (${INPUT}/helix-DWI.nhdr,helix-DWI.raw.gz)
#
# DWIJointRicianLMMSEFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# ResampleDTIVolume/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => skipping addition of DATA{}:  ${INPUT}/rotation.tfm
# => skipping addition of DATA{}:  ${INPUT}/rotationAndAffine.tfm
# => skipping addition of DATA{}:  ${INPUT}/FastNonrigidBSplineregistrationTransform.tfm
# => skipping addition of DATA{}:  ${INPUT}/affine.tfm
# => skipping addition of DATA{}:  ${BASELINE}/Brain_slice.nrrd
#
# CastScalarVolume/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# ThresholdScalarVolume/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
# => [data_association] (${BASELINE}/${CLP}Test.nhdr,ThresholdScalarVolumeTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ThresholdScalarVolume/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/ThresholdScalarVolume/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# RobustStatisticsSegmenter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# LabelMapSmoothing/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
# => [data_association] (${BASELINE}/LabelMapSmoothingTest.nhdr,LabelMapSmoothingTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadResampledOtsuSegmented.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/LabelMapSmoothing/Testing/../Data/Input/CTHeadResampledOtsuSegmented.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadResampledOtsuSegmented.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/LabelMapSmoothing/Testing/../Data/Input [created]
# => CTHeadResampledOtsuSegmented.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadResampledOtsuSegmented.nhdr,CTHeadResampledOtsuSegmented.raw.gz)
#
# BSplineToDeformationField/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# MaskScalarVolume/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/MaskScalarVolume/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/MaskScalarVolume/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# DiffusionTensorScalarMeasurements/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helix-DTI.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionTensorScalarMeasurements/Testing/../Data/Input/helix-DTI.nhdr
# => [global_test_data_dir -> module_input_dir] helix-DTI.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionTensorScalarMeasurements/Testing/../Data/Input [created]
# => helix-DTI.raw.gz [copied]
# => [data_association] (${INPUT}/helix-DTI.nhdr,helix-DTI.raw.gz)
#
# HistogramMatching/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
# => [data_association] (${BASELINE}/HistogramMatchingTest.nhdr,HistogramMatchingTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/HistogramMatching/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/HistogramMatching/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/HistogramMatching/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# PETStandardUptakeValueComputation/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# GradientAnisotropicDiffusion/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
# => [data_association] (${BASELINE}/GradientAnisotropicDiffusionTestWithImageSpacingOff.nhdr,GradientAnisotropicDiffusionTestWithImageSpacingOff.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/GradientAnisotropicDiffusion/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/GradientAnisotropicDiffusion/Testing/../Data/Input [created]
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
# => [data_association] (${BASELINE}/GradientAnisotropicDiffusionTestWithImageSpacingOn.nhdr,GradientAnisotropicDiffusionTestWithImageSpacingOn.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/GradientAnisotropicDiffusion/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# CurvatureAnisotropicDiffusion/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/${CLP}Test.nhdr,CurvatureAnisotropicDiffusionTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/CurvatureAnisotropicDiffusion/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/CurvatureAnisotropicDiffusion/Testing/../Data/Input [created]
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# ModelMaker/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helix-roi-lable2.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input/helix-roi-lable2.nrrd
# => [global_test_data_dir -> module_input_dir] helix-roi-lable2.nrrd
# => /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input [created]
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helix-roi-lable2.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input/helix-roi-lable2.nrrd
# => [global_test_data_dir -> module_input_dir] helix-roi-lable2.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helixMask3Labels.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input/helixMask3Labels.nrrd
# => [global_test_data_dir -> module_input_dir] helixMask3Labels.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helixMask3Labels.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input/helixMask3Labels.nrrd
# => [global_test_data_dir -> module_input_dir] helixMask3Labels.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helixMask3Labels.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input/helixMask3Labels.nrrd
# => [global_test_data_dir -> module_input_dir] helixMask3Labels.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helixMask3Labels.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input/helixMask3Labels.nrrd
# => [global_test_data_dir -> module_input_dir] helixMask3Labels.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helixMask3Labels.mrml
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input/helixMask3Labels.mrml
# => [global_test_data_dir -> module_input_dir] helixMask3Labels.mrml
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helixMask3Labels.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ModelMaker/Testing/../Data/Input/helixMask3Labels.nrrd
# => [global_test_data_dir -> module_input_dir] helixMask3Labels.nrrd
#
# BlobDetection/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# MultiplyScalarVolumes/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
# => [data_association] (${BASELINE}/${CLP}Test.nrrd,:)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/MultiplyScalarVolumes/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/MultiplyScalarVolumes/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/MultiplyScalarVolumes/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# ExecutionModelTour/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/ExecutionModelTourTest.mrml
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input/ExecutionModelTourTest.mrml
# => [global_test_data_dir -> module_input_dir] ExecutionModelTourTest.mrml
# => /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input [created]
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/ExecutionModelTourTest.mrml
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input/ExecutionModelTourTest.mrml
# => [global_test_data_dir -> module_input_dir] ExecutionModelTourTest.mrml
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# CheckerBoardFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
# => [data_association] (${BASELINE}/${CLP}Test.nhdr,CheckerBoardFilterTest.raw)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/CheckerBoardFilter/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/CheckerBoardFilter/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# TractographyLabelMapSeeding/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helix-DTI.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/TractographyLabelMapSeeding/Testing/../Data/Input/helix-DTI.nhdr
# => [global_test_data_dir -> module_input_dir] helix-DTI.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/TractographyLabelMapSeeding/Testing/../Data/Input [created]
# => helix-DTI.raw.gz [copied]
# => [data_association] (${INPUT}/helix-DTI.nhdr,helix-DTI.raw.gz)
#
# DWIUnbiasedNonLocalMeansFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# N4ITKBiasFieldCorrection/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/he3mask.nii.gz
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/N4ITKBiasFieldCorrection/Testing/../Data/Input/he3mask.nii.gz
# => [global_test_data_dir -> module_input_dir] he3mask.nii.gz
# => /home/jcfr/Projects/Slicer/Modules/CLI/N4ITKBiasFieldCorrection/Testing/../Data/Input [created]
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/he3volume.nii.gz
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/N4ITKBiasFieldCorrection/Testing/../Data/Input/he3volume.nii.gz
# => [global_test_data_dir -> module_input_dir] he3volume.nii.gz
#
# GrayscaleModelMaker/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleModelMaker/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleModelMaker/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# ExpertAutomatedRegistration/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => skipping addition of DATA{}:  ${INPUT}/RigidUNC24.tfm
# => skipping addition of DATA{}:  ${INPUT}/AffineUNC24.tfm
# => skipping addition of DATA{}:  ${INPUT}/BSplineUNC24.tfm
#
# AddScalarVolumes/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/${CLP}Test.nhdr,AddScalarVolumesTest.raw)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/AddScalarVolumes/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/AddScalarVolumes/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# OrientScalarVolume/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/fixed.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/OrientScalarVolume/Testing/../Data/Input/fixed.nrrd
# => [global_test_data_dir -> module_input_dir] fixed.nrrd
# => /home/jcfr/Projects/Slicer/Modules/CLI/OrientScalarVolume/Testing/../Data/Input [created]
#
# ACPCTransform/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/ACPCTest.mrml
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ACPCTransform/Testing/../Data/Input/ACPCTest.mrml
# => [global_test_data_dir -> module_input_dir] ACPCTest.mrml
# => /home/jcfr/Projects/Slicer/Modules/CLI/ACPCTransform/Testing/../Data/Input [created]
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/ACPC.fcsv
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ACPCTransform/Testing/../Data/Input/ACPC.fcsv
# => [global_test_data_dir -> module_input_dir] ACPC.fcsv
#
# GrayscaleGrindPeakImageFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/GrayscaleGrindPeakTest.nhdr,GrayscaleGrindPeakTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleGrindPeakImageFilter/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleGrindPeakImageFilter/Testing/../Data/Input [created]
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# DWIToDTIEstimation/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helix-DWI-otsu-no_islands-05.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/DWIToDTIEstimation/Testing/../Data/Input/helix-DWI-otsu-no_islands-05.nrrd
# => [global_test_data_dir -> module_input_dir] helix-DWI-otsu-no_islands-05.nrrd
# => /home/jcfr/Projects/Slicer/Modules/CLI/DWIToDTIEstimation/Testing/../Data/Input [created]
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helix-DWI.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/DWIToDTIEstimation/Testing/../Data/Input/helix-DWI.nhdr
# => [global_test_data_dir -> module_input_dir] helix-DWI.nhdr
# => helix-DWI.raw.gz [copied]
# => [data_association] (${INPUT}/helix-DWI.nhdr,helix-DWI.raw.gz)
#
# GrayscaleFillHoleImageFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/GrayscaleFillHoleTest.nhdr,GrayscaleFillHoleTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleFillHoleImageFilter/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleFillHoleImageFilter/Testing/../Data/Input [created]
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# SubtractScalarVolumes/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/${CLP}Test.nhdr,SubtractScalarVolumesTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/SubtractScalarVolumes/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/SubtractScalarVolumes/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxialDoubled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/SubtractScalarVolumes/Testing/../Data/Input/CTHeadAxialDoubled.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxialDoubled.nhdr
# => CTHeadAxialDoubled.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxialDoubled.nhdr,CTHeadAxialDoubled.raw.gz)
#
# ExtractSkeleton/Testing/CMakeLists.txt
# => [footer skip] (already appended)
#
# ModelToLabelMap/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/OAS10001.mha,:)
# => [data_association] (${INPUT}/OAS10001.hdr,OAS10001.img)
#
# MedianImageFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/MedianImageFilterTest.nhdr,MedianImageFilterTest.raw)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/MedianImageFilter/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/MedianImageFilter/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# VotingBinaryHoleFillingImageFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/VotingBinaryHoleFillingImageFilterTest.nhdr,VotingBinaryHoleFillingImageFilterTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadResampledOtsuSegmented.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/VotingBinaryHoleFillingImageFilter/Testing/../Data/Input/CTHeadResampledOtsuSegmented.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadResampledOtsuSegmented.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/VotingBinaryHoleFillingImageFilter/Testing/../Data/Input [created]
# => CTHeadResampledOtsuSegmented.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadResampledOtsuSegmented.nhdr,CTHeadResampledOtsuSegmented.raw.gz)
#
# ImageLabelCombine/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# ConnectedComponent/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# ResampleScalarVectorDWIVolume/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input [created]
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampledRotationNN.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledRotationNN.nrrd
# => [global_test_data_dir -> module_input_dir] MRHeadResampledRotationNN.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampledRotationAndAffine.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledRotationAndAffine.nrrd
# => [global_test_data_dir -> module_input_dir] MRHeadResampledRotationAndAffine.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampledBSplineWSInterpolationTest.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledBSplineWSInterpolationTest.nrrd
# => [global_test_data_dir -> module_input_dir] MRHeadResampledBSplineWSInterpolationTest.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampledBSplineInterpolationTest.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledBSplineInterpolationTest.nrrd
# => [global_test_data_dir -> module_input_dir] MRHeadResampledBSplineInterpolationTest.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampledHFieldTest.nrrd
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledHFieldTest.nrrd
# => [global_test_data_dir -> module_input_dir] MRHeadResampledHFieldTest.nrrd
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# DWIRicianLMMSEFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# DTIImportExport/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# FiducialRegistration/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# ResampleScalarVolume/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
# => [data_association] (${BASELINE}/${CLP}Test.nhdr,ResampleScalarVolumeTest.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/MRHeadResampled.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => [global_test_data_dir -> module_input_dir] MRHeadResampled.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVolume/Testing/../Data/Input [created]
# => MRHeadResampled.raw.gz [copied]
# => [data_association] (${INPUT}/MRHeadResampled.nhdr,MRHeadResampled.raw.gz)
#
# MergeModels/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/sphere.vtk
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input/sphere.vtk
# => [global_test_data_dir -> module_input_dir] sphere.vtk
# => /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input [created]
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/cube.vtk
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input/cube.vtk
# => [global_test_data_dir -> module_input_dir] cube.vtk
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/sphere.vtp
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input/sphere.vtp
# => [global_test_data_dir -> module_input_dir] sphere.vtp
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/cube.vtp
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input/cube.vtp
# => [global_test_data_dir -> module_input_dir] cube.vtp
#
# DiffusionTensorTest/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helix-DTI.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionTensorTest/Testing/../Data/Input/helix-DTI.nhdr
# => [global_test_data_dir -> module_input_dir] helix-DTI.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionTensorTest/Testing/../Data/Input [created]
# => helix-DTI.raw.gz [copied]
# => [data_association] (${INPUT}/helix-DTI.nhdr,helix-DTI.raw.gz)
#
# CreateDICOMSeries/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/CreateDICOMSeries/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/CreateDICOMSeries/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# GaussianBlurImageFilter/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
# => [data_association] (${BASELINE}/GaussianBlurImageFilterTest.nhdr,GaussianBlurImageFilterTest.raw)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/GaussianBlurImageFilter/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/GaussianBlurImageFilter/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# TestGridTransformRegistration/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: True)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/TestGridTransformRegistration/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => /home/jcfr/Projects/Slicer/Modules/CLI/TestGridTransformRegistration/Testing/../Data/Input [created]
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# => [data_filepath] /home/jcfr/Projects/Slicer/Testing/Data/Input/CTHeadAxial.nhdr
# => [dest_data_filepath] /home/jcfr/Projects/Slicer/Modules/CLI/TestGridTransformRegistration/Testing/../Data/Input/CTHeadAxial.nhdr
# => [global_test_data_dir -> module_input_dir] CTHeadAxial.nhdr
# => CTHeadAxial.raw.gz [copied]
# => [data_association] (${INPUT}/CTHeadAxial.nhdr,CTHeadAxial.raw.gz)
#
# FreesurferSurfaceSectionExtraction/Testing/CMakeLists.txt
# => [footer ok] (lastline_empty: False)
#
# ********************************************************************************
# Midas: Create module directories and upload missing input test data
# ********************************************************************************
# MergeModels [folder_id:3157]
# MergeModels uploading /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input/sphere.vtk
# => found item: 219927
# => md5(sphere.vtk): 0a3ad218528599b8a1888d870c784b7f
# => adding reference to existing bitstream
# Done
# MergeModels uploading /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input/cube.vtk
# => found item: 219928
# => md5(cube.vtk): f07b68414bb1348370427acb460a6507
# => adding reference to existing bitstream
# Done
# MergeModels uploading /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input/sphere.vtp
# => found item: 219929
# => md5(sphere.vtp): 60ee31b53c9d563566f16ba79c5513b4
# => adding reference to existing bitstream
# Done
# MergeModels uploading /home/jcfr/Projects/Slicer/Modules/CLI/MergeModels/Testing/../Data/Input/cube.vtp
# => found item: 219930
# => md5(cube.vtp): 8ea396486a1db931307410cdaf672d5a
# => adding reference to existing bitstream
# Done
# ACPCTransform [folder_id:3163]
# ACPCTransform uploading /home/jcfr/Projects/Slicer/Modules/CLI/ACPCTransform/Testing/../Data/Input/ACPCTest.mrml
# => found item: 220301
# => md5(ACPCTest.mrml): f7703cd7f30460349e4236cdfdf2763c
# => adding reference to existing bitstream
# Done
# ACPCTransform uploading /home/jcfr/Projects/Slicer/Modules/CLI/ACPCTransform/Testing/../Data/Input/ACPC.fcsv
# => found item: 220302
# => md5(ACPC.fcsv): 28bcba87c19fa050ed92cd77923d6214
# => adding reference to existing bitstream
# Done
# TractographyLabelMapSeeding [folder_id:3167]
# TractographyLabelMapSeeding uploading /home/jcfr/Projects/Slicer/Modules/CLI/TractographyLabelMapSeeding/Testing/../Data/Input/helix-DTI.nhdr
# => item created: 220304
# => md5(helix-DTI.nhdr): a9ea911664e286b7aadc440bf2ebc9d7
# Done
# MedianImageFilter [folder_id:3110]
# MedianImageFilter uploading /home/jcfr/Projects/Slicer/Modules/CLI/MedianImageFilter/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219681
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# ExecutionModelTour [folder_id:3171]
# ExecutionModelTour uploading /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input/ExecutionModelTourTest.mrml
# => item created: 220305
# => md5(ExecutionModelTourTest.mrml): 38c2a4bdc71671790dade7ce60d4f226
# Done
# ExecutionModelTour uploading /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input/ExecutionModelTourTest.mrml
# => found item: 220305
# => md5(ExecutionModelTourTest.mrml): 38c2a4bdc71671790dade7ce60d4f226
# => adding reference to existing bitstream
# Done
# ExecutionModelTour uploading /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input/MRHeadResampled.nhdr
# => item created: 220306
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ExecutionModelTour uploading /home/jcfr/Projects/Slicer/Modules/CLI/ExecutionModelTour/Testing/../Data/Input/CTHeadAxial.nhdr
# => item created: 220307
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# GradientAnisotropicDiffusion [folder_id:3119]
# GradientAnisotropicDiffusion uploading /home/jcfr/Projects/Slicer/Modules/CLI/GradientAnisotropicDiffusion/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 219692
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# GradientAnisotropicDiffusion uploading /home/jcfr/Projects/Slicer/Modules/CLI/GradientAnisotropicDiffusion/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 219692
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# N4ITKBiasFieldCorrection [folder_id:3172]
# N4ITKBiasFieldCorrection uploading /home/jcfr/Projects/Slicer/Modules/CLI/N4ITKBiasFieldCorrection/Testing/../Data/Input/he3mask.nii.gz
# => item created: 220308
# => md5(he3mask.nii.gz): 59f540277ad6fb9f8c20dfcdf3db743b
# Done
# N4ITKBiasFieldCorrection uploading /home/jcfr/Projects/Slicer/Modules/CLI/N4ITKBiasFieldCorrection/Testing/../Data/Input/he3volume.nii.gz
# => item created: 220309
# => md5(he3volume.nii.gz): 59877231fd80c069ee81155aaef1cfea
# Done
# ThresholdScalarVolume [folder_id:3109]
# ThresholdScalarVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ThresholdScalarVolume/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219680
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# GrayscaleGrindPeakImageFilter [folder_id:3108]
# GrayscaleGrindPeakImageFilter uploading /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleGrindPeakImageFilter/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 219679
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ResampleScalarVolume [folder_id:3115]
# ResampleScalarVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 219686
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# CurvatureAnisotropicDiffusion [folder_id:3120]
# CurvatureAnisotropicDiffusion uploading /home/jcfr/Projects/Slicer/Modules/CLI/CurvatureAnisotropicDiffusion/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 219694
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# OrientScalarVolume [folder_id:3173]
# OrientScalarVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/OrientScalarVolume/Testing/../Data/Input/fixed.nrrd
# => item created: 220310
# => md5(fixed.nrrd): e9cb63be38da99f2e93df44543016c44
# => adding reference to existing bitstream
# Done
# GaussianBlurImageFilter [folder_id:3122]
# GaussianBlurImageFilter uploading /home/jcfr/Projects/Slicer/Modules/CLI/GaussianBlurImageFilter/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219673
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# DiffusionTensorTest [folder_id:3177]
# DiffusionTensorTest uploading /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionTensorTest/Testing/../Data/Input/helix-DTI.nhdr
# => item created: 220311
# => md5(helix-DTI.nhdr): a9ea911664e286b7aadc440bf2ebc9d7
# => adding reference to existing bitstream
# Done
# GrayscaleModelMaker [folder_id:3181]
# GrayscaleModelMaker uploading /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleModelMaker/Testing/../Data/Input/CTHeadAxial.nhdr
# => item created: 220312
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# TestGridTransformRegistration [folder_id:3185]
# TestGridTransformRegistration uploading /home/jcfr/Projects/Slicer/Modules/CLI/TestGridTransformRegistration/Testing/../Data/Input/CTHeadAxial.nhdr
# => item created: 220313
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# TestGridTransformRegistration uploading /home/jcfr/Projects/Slicer/Modules/CLI/TestGridTransformRegistration/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 220313
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# VotingBinaryHoleFillingImageFilter [folder_id:3112]
# VotingBinaryHoleFillingImageFilter uploading /home/jcfr/Projects/Slicer/Modules/CLI/VotingBinaryHoleFillingImageFilter/Testing/../Data/Input/CTHeadResampledOtsuSegmented.nhdr
# => found item: 219683
# => md5(CTHeadResampledOtsuSegmented.nhdr): ba7a79d44238c893af441f105bd762db
# => adding reference to existing bitstream
# Done
# MaskScalarVolume [folder_id:3114]
# MaskScalarVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/MaskScalarVolume/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219685
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# MultiplyScalarVolumes [folder_id:3116]
# MultiplyScalarVolumes uploading /home/jcfr/Projects/Slicer/Modules/CLI/MultiplyScalarVolumes/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219687
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# MultiplyScalarVolumes uploading /home/jcfr/Projects/Slicer/Modules/CLI/MultiplyScalarVolumes/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219687
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# AddScalarVolumes [folder_id:3118]
# AddScalarVolumes uploading /home/jcfr/Projects/Slicer/Modules/CLI/AddScalarVolumes/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219691
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# DWIToDTIEstimation [folder_id:3189]
# DWIToDTIEstimation uploading /home/jcfr/Projects/Slicer/Modules/CLI/DWIToDTIEstimation/Testing/../Data/Input/helix-DWI-otsu-no_islands-05.nrrd
# => item created: 220314
# => md5(helix-DWI-otsu-no_islands-05.nrrd): 686b449ae29014f4707431a3d9120dcb
# Done
# DWIToDTIEstimation uploading /home/jcfr/Projects/Slicer/Modules/CLI/DWIToDTIEstimation/Testing/../Data/Input/helix-DWI.nhdr
# => item created: 220315
# => md5(helix-DWI.nhdr): 5b89cfa7f777782cbfd80303f27e3120
# Done
# DiffusionTensorScalarMeasurements [folder_id:3193]
# DiffusionTensorScalarMeasurements uploading /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionTensorScalarMeasurements/Testing/../Data/Input/helix-DTI.nhdr
# => item created: 220316
# => md5(helix-DTI.nhdr): a9ea911664e286b7aadc440bf2ebc9d7
# => adding reference to existing bitstream
# Done
# GrayscaleFillHoleImageFilter [folder_id:3111]
# GrayscaleFillHoleImageFilter uploading /home/jcfr/Projects/Slicer/Modules/CLI/GrayscaleFillHoleImageFilter/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 219682
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# SubtractScalarVolumes [folder_id:3117]
# SubtractScalarVolumes uploading /home/jcfr/Projects/Slicer/Modules/CLI/SubtractScalarVolumes/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219689
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# SubtractScalarVolumes uploading /home/jcfr/Projects/Slicer/Modules/CLI/SubtractScalarVolumes/Testing/../Data/Input/CTHeadAxialDoubled.nhdr
# => found item: 219690
# => md5(CTHeadAxialDoubled.nhdr): 13da84f2bbe76f78ce3ff7cbb5dbc09d
# => adding reference to existing bitstream
# Done
# CreateDICOMSeries [folder_id:3106]
# CreateDICOMSeries uploading /home/jcfr/Projects/Slicer/Modules/CLI/CreateDICOMSeries/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219697
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# HistogramMatching [folder_id:3105]
# HistogramMatching uploading /home/jcfr/Projects/Slicer/Modules/CLI/HistogramMatching/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219675
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# HistogramMatching uploading /home/jcfr/Projects/Slicer/Modules/CLI/HistogramMatching/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 219676
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# CheckerBoardFilter [folder_id:3107]
# CheckerBoardFilter uploading /home/jcfr/Projects/Slicer/Modules/CLI/CheckerBoardFilter/Testing/../Data/Input/CTHeadAxial.nhdr
# => found item: 219678
# => md5(CTHeadAxial.nhdr): 6e5c289c73e14ba7a1b0f8aaf6ed249a
# => adding reference to existing bitstream
# Done
# DiffusionWeightedVolumeMasking [folder_id:3197]
# DiffusionWeightedVolumeMasking uploading /home/jcfr/Projects/Slicer/Modules/CLI/DiffusionWeightedVolumeMasking/Testing/../Data/Input/helix-DWI.nhdr
# => item created: 220317
# => md5(helix-DWI.nhdr): 5b89cfa7f777782cbfd80303f27e3120
# => adding reference to existing bitstream
# Done
# ResampleScalarVectorDWIVolume [folder_id:3201]
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => item created: 220318
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 220318
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 220318
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledRotationNN.nrrd
# => item created: 220319
# => md5(MRHeadResampledRotationNN.nrrd): 7bf881e8579bee901a6a9e15f8ff8ac5
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 220318
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledRotationAndAffine.nrrd
# => item created: 220320
# => md5(MRHeadResampledRotationAndAffine.nrrd): 68b1c898b7c78309dc2480bbbcf991f9
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 220318
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledBSplineWSInterpolationTest.nrrd
# => item created: 220321
# => md5(MRHeadResampledBSplineWSInterpolationTest.nrrd): a0e78171550143fd9caf23dae4a0368f
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 220318
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampledBSplineInterpolationTest.nrrd
# => item created: 220322
# => md5(MRHeadResampledBSplineInterpolationTest.nrrd): 22f920a0ea41c5c5253f61bc9abb6741
# Done
# ResampleScalarVectorDWIVolume uploading /home/jcfr/Projects/Slicer/Modules/CLI/ResampleScalarVectorDWIVolume/Testing/../Data/Input/MRHeadResampled.nhdr
# => found item: 220318
# => md5(MRHeadResampled.nhdr): e23393e77b1695c9ff9599d9a173736c
# => adding reference to existing bitstream
# Done
# ...
# => GradientAnisotropicDiffusionTestWithImageSpacingOn.raw.gz [removed]
# => [ok]
#
# MRHeadResampled.nhdr
# => MRHeadResampled.nhdr.md5 [done]
# => MRHeadResampled.nhdr.bkp [done]
# => MRHeadResampled.nhdr [removed]
# => [ok]
#
# MRHeadResampled.raw.gz
# => MRHeadResampled.raw.gz.md5 [done]
# => MRHeadResampled.raw.gz.bkp [done]
# => MRHeadResampled.raw.gz [removed]
# => [ok]
#
# GrayscaleFillHoleTest.raw.gz
# => GrayscaleFillHoleTest.raw.gz.md5 [done]
# => GrayscaleFillHoleTest.raw.gz.bkp [done]
# => GrayscaleFillHoleTest.raw.gz [removed]
# => [ok]
#
# GrayscaleFillHoleTest.nhdr
# => GrayscaleFillHoleTest.nhdr.md5 [done]
# => GrayscaleFillHoleTest.nhdr.bkp [done]
# => GrayscaleFillHoleTest.nhdr [removed]
# => [ok]
#
# MRHeadResampled.nhdr
# => MRHeadResampled.nhdr.md5 [done]
# => MRHeadResampled.nhdr.bkp [done]
# => MRHeadResampled.nhdr [removed]
# => [ok]
#
# MRHeadResampled.raw.gz
# => MRHeadResampled.raw.gz.md5 [done]
# => MRHeadResampled.raw.gz.bkp [done]
# => MRHeadResampled.raw.gz [removed]
# => [ok]
#
# GrayscaleGrindPeakTest.raw.gz
# => GrayscaleGrindPeakTest.raw.gz.md5 [done]
# => GrayscaleGrindPeakTest.raw.gz.bkp [done]
# => GrayscaleGrindPeakTest.raw.gz [removed]
# => [ok]
#
# GrayscaleGrindPeakTest.nhdr
# => GrayscaleGrindPeakTest.nhdr.md5 [done]
# => GrayscaleGrindPeakTest.nhdr.bkp [done]
# => GrayscaleGrindPeakTest.nhdr [removed]
# => [ok]
#
# MRHeadResampled.nhdr
# => MRHeadResampled.nhdr.md5 [done]
# => MRHeadResampled.nhdr.bkp [done]
# => MRHeadResampled.nhdr [removed]
# => [ok]
#
# MRHeadResampled.raw.gz
# => MRHeadResampled.raw.gz.md5 [done]
# => MRHeadResampled.raw.gz.bkp [done]
# => MRHeadResampled.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.raw.gz
# => CTHeadAxial.raw.gz.md5 [done]
# => CTHeadAxial.raw.gz.bkp [done]
# => CTHeadAxial.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.nhdr
# => CTHeadAxial.nhdr.md5 [done]
# => CTHeadAxial.nhdr.bkp [done]
# => CTHeadAxial.nhdr [removed]
# => [ok]
#
# HistogramMatchingTest.raw.gz
# => HistogramMatchingTest.raw.gz.md5 [done]
# => HistogramMatchingTest.raw.gz.bkp [done]
# => HistogramMatchingTest.raw.gz [removed]
# => [ok]
#
# HistogramMatchingTest.nhdr
# => HistogramMatchingTest.nhdr.md5 [done]
# => HistogramMatchingTest.nhdr.bkp [done]
# => HistogramMatchingTest.nhdr [removed]
# => [ok]
#
# CTHeadAxial.raw.gz
# => CTHeadAxial.raw.gz.md5 [done]
# => CTHeadAxial.raw.gz.bkp [done]
# => CTHeadAxial.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.nhdr
# => CTHeadAxial.nhdr.md5 [done]
# => CTHeadAxial.nhdr.bkp [done]
# => CTHeadAxial.nhdr [removed]
# => [ok]
#
# MRHeadResampled.nhdr
# => MRHeadResampled.nhdr.md5 [done]
# => MRHeadResampled.nhdr.bkp [done]
# => MRHeadResampled.nhdr [removed]
# => [ok]
#
# MRHeadResampled.raw.gz
# => MRHeadResampled.raw.gz.md5 [done]
# => MRHeadResampled.raw.gz.bkp [done]
# => MRHeadResampled.raw.gz [removed]
# => [ok]
#
# LabelMapSmoothingTest.nhdr
# => LabelMapSmoothingTest.nhdr.md5 [done]
# => LabelMapSmoothingTest.nhdr.bkp [done]
# => LabelMapSmoothingTest.nhdr [removed]
# => [ok]
#
# LabelMapSmoothingTest.raw.gz
# => LabelMapSmoothingTest.raw.gz.md5 [done]
# => LabelMapSmoothingTest.raw.gz.bkp [done]
# => LabelMapSmoothingTest.raw.gz [removed]
# => [ok]
#
# CTHeadResampledOtsuSegmented.raw.gz
# => CTHeadResampledOtsuSegmented.raw.gz.md5 [done]
# => CTHeadResampledOtsuSegmented.raw.gz.bkp [done]
# => CTHeadResampledOtsuSegmented.raw.gz [removed]
# => [ok]
#
# CTHeadResampledOtsuSegmented.nhdr
# => CTHeadResampledOtsuSegmented.nhdr.md5 [done]
# => CTHeadResampledOtsuSegmented.nhdr.bkp [done]
# => CTHeadResampledOtsuSegmented.nhdr [removed]
# => [ok]
#
# MaskedVolume.nrrd
# => MaskedVolume.nrrd.md5 [done]
# => MaskedVolume.nrrd.bkp [done]
# => MaskedVolume.nrrd [removed]
# => [ok]
#
# CTHeadAxial.raw.gz
# => CTHeadAxial.raw.gz.md5 [done]
# => CTHeadAxial.raw.gz.bkp [done]
# => CTHeadAxial.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.nhdr
# => CTHeadAxial.nhdr.md5 [done]
# => CTHeadAxial.nhdr.bkp [done]
# => CTHeadAxial.nhdr [removed]
# => [ok]
#
# MedianImageFilterTest.raw
# => MedianImageFilterTest.raw.md5 [done]
# => MedianImageFilterTest.raw.bkp [done]
# => MedianImageFilterTest.raw [removed]
# => [ok]
#
# MedianImageFilterTest.nhdr
# => MedianImageFilterTest.nhdr.md5 [done]
# => MedianImageFilterTest.nhdr.bkp [done]
# => MedianImageFilterTest.nhdr [removed]
# => [ok]
#
# CTHeadAxial.raw.gz
# => CTHeadAxial.raw.gz.md5 [done]
# => CTHeadAxial.raw.gz.bkp [done]
# => CTHeadAxial.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.nhdr
# => CTHeadAxial.nhdr.md5 [done]
# => CTHeadAxial.nhdr.bkp [done]
# => CTHeadAxial.nhdr [removed]
# => [ok]
#
# sphereCube.vtp
# => sphereCube.vtp.md5 [done]
# => sphereCube.vtp.bkp [done]
# => sphereCube.vtp [removed]
# => [ok]
#
# cube.vtp
# => cube.vtp.md5 [done]
# => cube.vtp.bkp [done]
# => cube.vtp [removed]
# => [ok]
#
# cube.vtk
# => cube.vtk.md5 [done]
# => cube.vtk.bkp [done]
# => cube.vtk [removed]
# => [ok]
#
# sphere.vtp
# => sphere.vtp.md5 [done]
# => sphere.vtp.bkp [done]
# => sphere.vtp [removed]
# => [ok]
#
# sphere.vtk
# => sphere.vtk.md5 [done]
# => sphere.vtk.bkp [done]
# => sphere.vtk [removed]
# => [ok]
#
# helix-roi-lable2.nrrd
# => helix-roi-lable2.nrrd.md5 [done]
# => helix-roi-lable2.nrrd.bkp [done]
# => helix-roi-lable2.nrrd [removed]
# => [ok]
#
# helixMask3Labels.mrml
# => helixMask3Labels.mrml.md5 [done]
# => helixMask3Labels.mrml.bkp [done]
# => helixMask3Labels.mrml [removed]
# => [ok]
#
# helixMask3Labels.nrrd
# => helixMask3Labels.nrrd.md5 [done]
# => helixMask3Labels.nrrd.bkp [done]
# => helixMask3Labels.nrrd [removed]
# => [ok]
#
# OAS10001.1.mha
# => OAS10001.1.mha.md5 [done]
# => OAS10001.1.mha.bkp [done]
# => OAS10001.1.mha [removed]
# => [ok]
#
# OAS10001.mha
# => OAS10001.mha.md5 [done]
# => OAS10001.mha.bkp [done]
# => OAS10001.mha [removed]
# => [ok]
#
# OAS10001.img
# => OAS10001.img.md5 [done]
# => OAS10001.img.bkp [done]
# => OAS10001.img [removed]
# => [ok]
#
# OAS10001.vtp
# => OAS10001.vtp.md5 [done]
# => OAS10001.vtp.bkp [done]
# => OAS10001.vtp [removed]
# => [ok]
#
# OAS10001.hdr
# => OAS10001.hdr.md5 [done]
# => OAS10001.hdr.bkp [done]
# => OAS10001.hdr [removed]
# => [ok]
#
# MultiplyScalarVolumesTest.1.nrrd
# => MultiplyScalarVolumesTest.1.nrrd.md5 [done]
# => MultiplyScalarVolumesTest.1.nrrd.bkp [done]
# => MultiplyScalarVolumesTest.1.nrrd [removed]
# => [ok]
#
# MultiplyScalarVolumesTest.nrrd
# => MultiplyScalarVolumesTest.nrrd.md5 [done]
# => MultiplyScalarVolumesTest.nrrd.bkp [done]
# => MultiplyScalarVolumesTest.nrrd [removed]
# => [ok]
#
# CTHeadAxial.raw.gz
# => CTHeadAxial.raw.gz.md5 [done]
# => CTHeadAxial.raw.gz.bkp [done]
# => CTHeadAxial.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.nhdr
# => CTHeadAxial.nhdr.md5 [done]
# => CTHeadAxial.nhdr.bkp [done]
# => CTHeadAxial.nhdr [removed]
# => [ok]
#
# he3corrected.nii.gz
# => he3corrected.nii.gz.md5 [done]
# => he3corrected.nii.gz.bkp [done]
# => he3corrected.nii.gz [removed]
# => [ok]
#
# he3biasfield.nii.gz
# => he3biasfield.nii.gz.md5 [done]
# => he3biasfield.nii.gz.bkp [done]
# => he3biasfield.nii.gz [removed]
# => [ok]
#
# he3mask.nii.gz
# => he3mask.nii.gz.md5 [done]
# => he3mask.nii.gz.bkp [done]
# => he3mask.nii.gz [removed]
# => [ok]
#
# he3volume.nii.gz
# => he3volume.nii.gz.md5 [done]
# => he3volume.nii.gz.bkp [done]
# => he3volume.nii.gz [removed]
# => [ok]
#
# OrientScalarVolumeTestAxial.nrrd
# => OrientScalarVolumeTestAxial.nrrd.md5 [done]
# => OrientScalarVolumeTestAxial.nrrd.bkp [done]
# => OrientScalarVolumeTestAxial.nrrd [removed]
# => [ok]
#
# OrientScalarVolumeTestCoronal.nrrd
# => OrientScalarVolumeTestCoronal.nrrd.md5 [done]
# => OrientScalarVolumeTestCoronal.nrrd.bkp [done]
# => OrientScalarVolumeTestCoronal.nrrd [removed]
# => [ok]
#
# OrientScalarVolumeTestSagittal.nrrd
# => OrientScalarVolumeTestSagittal.nrrd.md5 [done]
# => OrientScalarVolumeTestSagittal.nrrd.bkp [done]
# => OrientScalarVolumeTestSagittal.nrrd [removed]
# => [ok]
#
# fixed.nrrd
# => fixed.nrrd.md5 [done]
# => fixed.nrrd.bkp [done]
# => fixed.nrrd [removed]
# => [ok]
#
# dt-helix-ref-BS.nrrd
# => dt-helix-ref-BS.nrrd.md5 [done]
# => dt-helix-ref-BS.nrrd.bkp [done]
# => dt-helix-ref-BS.nrrd [removed]
# => [ok]
#
# dt-helix-ref-BSInterpolation.nrrd
# => dt-helix-ref-BSInterpolation.nrrd.md5 [done]
# => dt-helix-ref-BSInterpolation.nrrd.bkp [done]
# => dt-helix-ref-BSInterpolation.nrrd [removed]
# => [ok]
#
# dt-helix-ref-HField.nrrd
# => dt-helix-ref-HField.nrrd.md5 [done]
# => dt-helix-ref-HField.nrrd.bkp [done]
# => dt-helix-ref-HField.nrrd [removed]
# => [ok]
#
# dt-helix-ref-Rotated.nrrd
# => dt-helix-ref-Rotated.nrrd.md5 [done]
# => dt-helix-ref-Rotated.nrrd.bkp [done]
# => dt-helix-ref-Rotated.nrrd [removed]
# => [ok]
#
# Brain_slice.nrrd
#
# Brain_slice.nrrd skipping
#
# dt-helix-ref-RotationAndAffine.nrrd
# => dt-helix-ref-RotationAndAffine.nrrd.md5 [done]
# => dt-helix-ref-RotationAndAffine.nrrd.bkp [done]
# => dt-helix-ref-RotationAndAffine.nrrd [removed]
# => [ok]
#
# FastNonrigidBSplineregistrationTransform.tfm
# => [ok]
#
# affine.tfm
# => [ok]
#
# rotationAndAffine.tfm
# => [ok]
#
# deformationField.nrrd
# => deformationField.nrrd.md5 [done]
# => deformationField.nrrd.bkp [done]
# => deformationField.nrrd [removed]
# => [ok]
#
# dt-helix.nrrd
# => dt-helix.nrrd.md5 [done]
# => dt-helix.nrrd.bkp [done]
# => dt-helix.nrrd [removed]
# => [ok]
#
# rotation.tfm
# => [ok]
#
# MRHeadResampledHFieldTest.nrrd
# => MRHeadResampledHFieldTest.nrrd.md5 [done]
# => MRHeadResampledHFieldTest.nrrd.bkp [done]
# => MRHeadResampledHFieldTest.nrrd [removed]
# => [ok]
#
# MRHeadResampledRotationAndAffine.nrrd
# => MRHeadResampledRotationAndAffine.nrrd.md5 [done]
# => MRHeadResampledRotationAndAffine.nrrd.bkp [done]
# => MRHeadResampledRotationAndAffine.nrrd [removed]
# => [ok]
#
# MRHeadResampledBSplineWSInterpolationTest.nrrd
# => MRHeadResampledBSplineWSInterpolationTest.nrrd.md5 [done]
# => MRHeadResampledBSplineWSInterpolationTest.nrrd.bkp [done]
# => MRHeadResampledBSplineWSInterpolationTest.nrrd [removed]
# => [ok]
#
# MRHeadResampledRotationNN.nrrd
# => MRHeadResampledRotationNN.nrrd.md5 [done]
# => MRHeadResampledRotationNN.nrrd.bkp [done]
# => MRHeadResampledRotationNN.nrrd [removed]
# => [ok]
#
# MRHeadResampled.nhdr
# => MRHeadResampled.nhdr.md5 [done]
# => MRHeadResampled.nhdr.bkp [done]
# => MRHeadResampled.nhdr [removed]
# => [ok]
#
# MRHeadResampledBSplineInterpolationTest.nrrd
# => MRHeadResampledBSplineInterpolationTest.nrrd.md5 [done]
# => MRHeadResampledBSplineInterpolationTest.nrrd.bkp [done]
# => MRHeadResampledBSplineInterpolationTest.nrrd [removed]
# => [ok]
#
# MRHeadResampled.raw.gz
# => MRHeadResampled.raw.gz.md5 [done]
# => MRHeadResampled.raw.gz.bkp [done]
# => MRHeadResampled.raw.gz [removed]
# => [ok]
#
# ResampleScalarVolumeTest.raw.gz
# => ResampleScalarVolumeTest.raw.gz.md5 [done]
# => ResampleScalarVolumeTest.raw.gz.bkp [done]
# => ResampleScalarVolumeTest.raw.gz [removed]
# => [ok]
#
# ResampleScalarVolumeTest.nhdr
# => ResampleScalarVolumeTest.nhdr.md5 [done]
# => ResampleScalarVolumeTest.nhdr.bkp [done]
# => ResampleScalarVolumeTest.nhdr [removed]
# => [ok]
#
# MRHeadResampled.nhdr
# => MRHeadResampled.nhdr.md5 [done]
# => MRHeadResampled.nhdr.bkp [done]
# => MRHeadResampled.nhdr [removed]
# => [ok]
#
# MRHeadResampled.raw.gz
# => MRHeadResampled.raw.gz.md5 [done]
# => MRHeadResampled.raw.gz.bkp [done]
# => MRHeadResampled.raw.gz [removed]
# => [ok]
#
# grayscale.nrrd
# => grayscale.nrrd.md5 [done]
# => grayscale.nrrd.bkp [done]
# => grayscale.nrrd [removed]
# => [ok]
#
# grayscale-label.nrrd
# => grayscale-label.nrrd.md5 [done]
# => grayscale-label.nrrd.bkp [done]
# => grayscale-label.nrrd [removed]
# => [ok]
#
# SimpleRegionGrowingSegmentationTest.nhdr
# => SimpleRegionGrowingSegmentationTest.nhdr.md5 [done]
# => SimpleRegionGrowingSegmentationTest.nhdr.bkp [done]
# => SimpleRegionGrowingSegmentationTest.nhdr [removed]
# => [ok]
#
# SimpleRegionGrowingSegmentationTest.raw.gz
# => SimpleRegionGrowingSegmentationTest.raw.gz.md5 [done]
# => SimpleRegionGrowingSegmentationTest.raw.gz.bkp [done]
# => SimpleRegionGrowingSegmentationTest.raw.gz [removed]
# => [ok]
#
# MRHeadResampled.nhdr
# => MRHeadResampled.nhdr.md5 [done]
# => MRHeadResampled.nhdr.bkp [done]
# => MRHeadResampled.nhdr [removed]
# => [ok]
#
# MRHeadResampled.raw.gz
# => MRHeadResampled.raw.gz.md5 [done]
# => MRHeadResampled.raw.gz.bkp [done]
# => MRHeadResampled.raw.gz [removed]
# => [ok]
#
# SubtractScalarVolumesTest.nhdr
# => SubtractScalarVolumesTest.nhdr.md5 [done]
# => SubtractScalarVolumesTest.nhdr.bkp [done]
# => SubtractScalarVolumesTest.nhdr [removed]
# => [ok]
#
# SubtractScalarVolumesTest.raw.gz
# => SubtractScalarVolumesTest.raw.gz.md5 [done]
# => SubtractScalarVolumesTest.raw.gz.bkp [done]
# => SubtractScalarVolumesTest.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.raw.gz
# => CTHeadAxial.raw.gz.md5 [done]
# => CTHeadAxial.raw.gz.bkp [done]
# => CTHeadAxial.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.nhdr
# => CTHeadAxial.nhdr.md5 [done]
# => CTHeadAxial.nhdr.bkp [done]
# => CTHeadAxial.nhdr [removed]
# => [ok]
#
# CTHeadAxialDoubled.raw.gz
# => CTHeadAxialDoubled.raw.gz.md5 [done]
# => CTHeadAxialDoubled.raw.gz.bkp [done]
# => CTHeadAxialDoubled.raw.gz [removed]
# => [ok]
#
# CTHeadAxialDoubled.nhdr
# => CTHeadAxialDoubled.nhdr.md5 [done]
# => CTHeadAxialDoubled.nhdr.bkp [done]
# => CTHeadAxialDoubled.nhdr [removed]
# => [ok]
#
# CTHeadAxial.raw.gz
# => CTHeadAxial.raw.gz.md5 [done]
# => CTHeadAxial.raw.gz.bkp [done]
# => CTHeadAxial.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.nhdr
# => CTHeadAxial.nhdr.md5 [done]
# => CTHeadAxial.nhdr.bkp [done]
# => CTHeadAxial.nhdr [removed]
# => [ok]
#
# ThresholdScalarVolumeTest.raw.gz
# => ThresholdScalarVolumeTest.raw.gz.md5 [done]
# => ThresholdScalarVolumeTest.raw.gz.bkp [done]
# => ThresholdScalarVolumeTest.raw.gz [removed]
# => [ok]
#
# ThresholdScalarVolumeTest.nhdr
# => ThresholdScalarVolumeTest.nhdr.md5 [done]
# => ThresholdScalarVolumeTest.nhdr.bkp [done]
# => ThresholdScalarVolumeTest.nhdr [removed]
# => [ok]
#
# CTHeadAxial.raw.gz
# => CTHeadAxial.raw.gz.md5 [done]
# => CTHeadAxial.raw.gz.bkp [done]
# => CTHeadAxial.raw.gz [removed]
# => [ok]
#
# CTHeadAxial.nhdr
# => CTHeadAxial.nhdr.md5 [done]
# => CTHeadAxial.nhdr.bkp [done]
# => CTHeadAxial.nhdr [removed]
# => [ok]
#
# helix-DTI.raw.gz
# => helix-DTI.raw.gz.md5 [done]
# => helix-DTI.raw.gz.bkp [done]
# => helix-DTI.raw.gz [removed]
# => [ok]
#
# helix-DTI.nhdr
# => helix-DTI.nhdr.md5 [done]
# => helix-DTI.nhdr.bkp [done]
# => helix-DTI.nhdr [removed]
# => [ok]
#
# VotingBinaryHoleFillingImageFilterTest.raw.gz
# => VotingBinaryHoleFillingImageFilterTest.raw.gz.md5 [done]
# => VotingBinaryHoleFillingImageFilterTest.raw.gz.bkp [done]
# => VotingBinaryHoleFillingImageFilterTest.raw.gz [removed]
# => [ok]
#
# VotingBinaryHoleFillingImageFilterTest.nhdr
# => VotingBinaryHoleFillingImageFilterTest.nhdr.md5 [done]
# => VotingBinaryHoleFillingImageFilterTest.nhdr.bkp [done]
# => VotingBinaryHoleFillingImageFilterTest.nhdr [removed]
# => [ok]
#
# CTHeadResampledOtsuSegmented.raw.gz
# => CTHeadResampledOtsuSegmented.raw.gz.md5 [done]
# => CTHeadResampledOtsuSegmented.raw.gz.bkp [done]
# => CTHeadResampledOtsuSegmented.raw.gz [removed]
# => [ok]
#
# CTHeadResampledOtsuSegmented.nhdr
# => CTHeadResampledOtsuSegmented.nhdr.md5 [done]
# => CTHeadResampledOtsuSegmented.nhdr.bkp [done]
# => CTHeadResampledOtsuSegmented.nhdr [removed]
# => [ok]
#
#
# ctest -R ProbeVolumeWithModel
# ctest -R SimpleRegionGrowingSegmentation
# ctest -R DiffusionWeightedVolumeMasking
# ctest -R DWIJointRicianLMMSEFilter
# ctest -R ResampleDTIVolume
# ctest -R CastScalarVolume
# ctest -R ThresholdScalarVolume
# ctest -R RobustStatisticsSegmenter
# ctest -R LabelMapSmoothing
# ctest -R BSplineToDeformationField
# ctest -R MaskScalarVolume
# ctest -R DiffusionTensorScalarMeasurements
# ctest -R HistogramMatching
# ctest -R PETStandardUptakeValueComputation
# ctest -R GradientAnisotropicDiffusion
# ctest -R CurvatureAnisotropicDiffusion
# ctest -R ModelMaker
# ctest -R BlobDetection
# ctest -R MultiplyScalarVolumes
# ctest -R ExecutionModelTour
# ctest -R CheckerBoardFilter
# ctest -R TractographyLabelMapSeeding
# ctest -R DWIUnbiasedNonLocalMeansFilter
# ctest -R N4ITKBiasFieldCorrection
# ctest -R GrayscaleModelMaker
# ctest -R ExpertAutomatedRegistration
# ctest -R AddScalarVolumes
# ctest -R OrientScalarVolume
# ctest -R ACPCTransform
# ctest -R GrayscaleGrindPeakImageFilter
# ctest -R DWIToDTIEstimation
# ctest -R GrayscaleFillHoleImageFilter
# ctest -R SubtractScalarVolumes
# ctest -R ExtractSkeleton
# ctest -R ModelToLabelMap
# ctest -R MedianImageFilter
# ctest -R VotingBinaryHoleFillingImageFilter
# ctest -R ImageLabelCombine
# ctest -R ConnectedComponent
# ctest -R ResampleScalarVectorDWIVolume
# ctest -R DWIRicianLMMSEFilter
# ctest -R DTIImportExport
# ctest -R FiducialRegistration
# ctest -R ResampleScalarVolume
# ctest -R MergeModels
# ctest -R DiffusionTensorTest
# ctest -R CreateDICOMSeries
# ctest -R GaussianBlurImageFilter
# ctest -R TestGridTransformRegistration
# ctest -R FreesurferSurfaceSectionExtraction

# %%
#---------------------------------------------------------------------------
def remove_matching_lines(cmakelist, regex):
    p = re.compile(regex)
    updated_lines = []
    removed = 0
    with open(cmakelist, 'r') as myfile:
        lines = myfile.readlines()
        for line in lines:
            if not p.match(line):
                updated_lines.append(line)
            else:
                removed = removed + 1
    with open(cmakelist, "w") as myfile:
        myfile.writelines(updated_lines)
    return removed > 0

#---------------------------------------------------------------------------
def add_line_after(cmakelist, regex, line_to_add):
    p = re.compile(regex)
    updated_lines = []
    added = 0
    with open(cmakelist, 'r') as myfile:
        lines = myfile.readlines()
        for line in lines:
            updated_lines.append(line)
            if p.match(line):
                updated_lines.append(line_to_add + '\n')
                added = added + 1
    if not added <= 1:
        raise Exception("File '%s' is expected to have only one line matching '%s'" % (cmakelist, regex))
    with open(cmakelist, "w") as myfile:
        myfile.writelines(updated_lines)
    return added > 0

cmakelist = '/home/jcfr/Projects/Slicer/Modules/CLI/N4ITKBiasFieldCorrection/Testing/CMakeLists.txt'

print("has_line: %d" % has_line(cmakelist,ur'^set\(TEST_DATA .+\)$'))

removed = remove_matching_lines(cmakelist, ur'^set\(TEST_DATA .+\)$')

added = False
if removed:
    added = add_line_after(cmakelist, ur'^set\(BASELINE .+\)$', 'set(INPUT )')
print(added)

def has_line(cmakelist, regex):
    p = re.compile(regex)
    with open(cmakelist, 'r') as myfile:
        for line in myfile.readlines():
            if p.match(line):
                return True
    return False
# Out:
# has_line: 1
# True

# %%
# %load_ext autoreload
# %autoreload 1

import hashlib
import os

# XXX Modified version of PyDas is used.
#     PR suubmitted: https://github.com/midasplatform/pydas/pull/27
# %aimport pydas

directory = '/home/jcfr/Projects/Slicer/Modules/CLI'


midas_url = 'http://slicer.kitware.com/midas3'
email = os.environ["MIDAS_PACKAGE_EMAIL"]
apikey = os.environ["MIDAS_PACKAGE_API_KEY"]
communicator = pydas.core.Communicator(midas_url)
token = communicator.login_with_api_key(email, apikey)


# Brain_slice.nrrd => 344c54d3f6121d0869490fcf9e4df491 [False]
# he3corrected.nii.gz => ba19967968f8b52ef0b30f0b0a5b8034 [False]
# he3biasfield.nii.gz => ff4af8062c3d051a9995f2d15c0eb4e2 [False]
# sphereCube.vtp => 5a1f33c8d3b49fd8fa7b3905b116ea9c [False]



#upload_revision(103396, os.path.join(directory, 'N4ITKBiasFieldCorrection/Data/Baseline', 'he3corrected.nii.gz'))
#upload_revision(103395, os.path.join(directory, 'N4ITKBiasFieldCorrection/Data/Baseline', 'he3biasfield.nii.gz'))
#upload_revision(103389, os.path.join(directory, 'MergeModels/Data/Baseline', 'sphereCube.vtp'))
#upload_item(1469, os.path.join(directory, 'ResampleDTIVolume/Data/Baseline', 'Brain_slice.nrrd'))

# %%
# %reload_ext autoreload
# %autoreload 1
# %aimport pydas

print("pydas.__file__: %s" % pydas.__file__)

import hashlib
import os

midas_url = 'http://slicer.kitware.com/midas3'
email = os.environ["MIDAS_PACKAGE_EMAIL"]
apikey = os.environ["MIDAS_PACKAGE_API_KEY"]
communicator = pydas.core.Communicator(midas_url)

def token(email, apikey):
    return communicator.login_with_api_key(email, apikey)

module_name = 'ModelMaker'

#test_data_folder_id = get_or_create_module_test_data_directory(module_name, 'Input')
#print(test_data_folder_id)

def md5(fname):
    hash = hashlib.md5()
    with open(fname) as f:
        for chunk in iter(lambda: f.read(4096), ""):
            hash.update(chunk)
    return hash.hexdigest()

def upload_revision(item_id, filepath, create_additional_revision=None):
    checksum = md5(filepath)
    filename = os.path.basename(filepath)
    print("=> md5(%s): %s" % (filename, checksum))
    upload_token = communicator.generate_upload_token(token(email, apikey), item_id, filename, checksum=checksum, create_additional_revision=create_additional_revision)
    if upload_token:
        print("upload_token: %s" % upload_token)
        if not create_additional_revision is None:
            communicator.perform_upload(upload_token, filename, item_id=item_id, filepath=filepath, create_additional_revision=create_additional_revision)
        else:
            communicator.perform_upload(upload_token, filename, item_id=item_id, filepath=filepath)
    else:
        print("No upload token available")
    print("Done")


#upload_revision(219925, '/home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helixMask3Labels.nrrd', True)
#upload_revision(219924, '/home/jcfr//Projects/sandbox/helix-roi-lable2.nrrd', True)
upload_revision(219924, '/home/jcfr/Projects/Slicer/Libs/MRML/Core/Testing/TestData/helixMask3Labels.nrrd', True)
# Out:
# pydas.__file__: /home/jcfr/Projects/pydas/pydas/__init__.pyc
# => md5(helixMask3Labels.nrrd): f3efa51f50c158ae1e35d55d2d4841a0
# No upload token available
# Done

# %%
# %reload_ext autoreload
# %autoreload 1
# %aimport pydas
import hashlib
import os
import time

midas_url = 'http://slicer.kitware.com/midas3'
email = os.environ["MIDAS_PACKAGE_EMAIL"]
apikey = os.environ["MIDAS_PACKAGE_API_KEY"]
communicator = pydas.core.Communicator(midas_url)
folder_id = 1654

def token(email, apikey):
    return communicator.login_with_api_key(email, apikey)

def md5(fname):
    hash = hashlib.md5()
    with open(fname) as f:
        for chunk in iter(lambda: f.read(4096), ""):
            hash.update(chunk)
    return hash.hexdigest()

def generate_file(filepath):
    with open(filepath, 'wb') as fout:
        fout.write(os.urandom(1024))
    filename = os.path.basename(filepath)
    checksum = md5(filepath)
    print("filepath: %s, md5: %s" % (filepath, checksum))
    return (filename, checksum)

prefix = str(int(time.time()))

# Create original file for item #1
filepath_item1 = './%s-bistream-1.bin' % prefix
(filename_item1, checksum_item1) = generate_file(filepath_item1)

# Create item #1
item = communicator.create_item(token(email, apikey), '%s-item1' % prefix, folder_id)
item_id = item['item_id']
print("item #1 created: %s" % (item_id))

# Upload initial revision into item #1
upload_token = communicator.generate_upload_token(token(email, apikey), item_id, filename_item1)
communicator.perform_upload(upload_token, filename_item1, item_id=item_id, filepath=filepath_item1)
print("item #1: initial revision created")

# Create original file for item #2
filepath_item2 = './%s-bistream-2.bin' % prefix
(filename_item2, checksum_item2) = generate_file(filepath_item2)

# Create item #2
item = communicator.create_item(token(email, apikey), '%s-item2' % prefix, folder_id)
item_id = item['item_id']
print("item #2 created: %s" % (item_id))

# Upload initial revision into item #2
upload_token = communicator.generate_upload_token(token(email, apikey), item_id, filename_item2)
communicator.perform_upload(upload_token, filename_item2, item_id=item_id, filepath=filepath_item2)
print("item #2: initial revision created")

# Upload an other revision into item #2 associating bitstream created for item #1
upload_token = communicator.generate_upload_token(token(email, apikey), item_id, filename_item1, checksum=checksum_item1, create_additional_revision=True)
print("item #2: other revision created")
if upload_token:
    raise Exception('item #2: upload_token is expected to be empty')
# Out:
# filepath: ./1445935181-bistream-1.bin, md5: 0e42e48b5b03bcca4675a35d7c817571
# item #1 created: 220267
# item #1: initial revision created
# filepath: ./1445935181-bistream-2.bin, md5: 1a4e27e5c241365add69a8c697922cb0
# item #2 created: 220268
# item #2: initial revision created
# item #2: other revision created

# %%
import time
print(int(time.time()))
# Out:
# 1445931026

# %%
x=[1, 2, 3]
y = [4, 5, 6]
z = [5, 8, 9]
import scipy.spatial

scipy.spatial.distance.cityblock(x, z)

s = 0
for i in range(3):
    s = s + abs(x[i] - z[i])
print(s)
# Out:
# 16
