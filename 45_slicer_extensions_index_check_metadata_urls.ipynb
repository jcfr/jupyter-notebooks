# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install retry joblib
# Out:
# Requirement already satisfied: retry in /home/jcfr/.virtualenvs/jupyter/lib/python3.8/site-packages (0.9.2)
# Requirement already satisfied: joblib in /home/jcfr/.virtualenvs/jupyter/lib/python3.8/site-packages (1.2.0)
# Requirement already satisfied: decorator>=3.4.2 in /home/jcfr/.virtualenvs/jupyter/lib/python3.8/site-packages (from retry) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /home/jcfr/.virtualenvs/jupyter/lib/python3.8/site-packages (from retry) (1.11.0)

# %%
import sys

# parse_s4ext
extensions_index_script_dir = '/home/jcfr/Projects/ExtensionsIndex/scripts/'
if extensions_index_script_dir not in sys.path:
    sys.path.insert(0, extensions_index_script_dir)

from check_description_files import parse_s4ext

# ExtensionProject
slicer_scripts_dir = "/tmp/SlicerWizard/Utilities/Scripts/"
if slicer_scripts_dir not in sys.path:
    sys.path.insert(0, slicer_scripts_dir)

from SlicerWizard.ExtensionProject import ExtensionProject

# %%
import errno
import os
    
# Copied from https://github.com/scikit-build/scikit-build/blob/master/skbuild/utils/__init__.py
def mkdir_p(path):
    """Ensure directory ``path`` exists. If needed, parent directories
    are created.
    Adapted from http://stackoverflow.com/a/600612/1539918
    """
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:  # pragma: no cover
            raise

# %%
import urllib.request

from socket import timeout as SocketTimeout
from http.client import HTTPException

from retry import retry

def check_url(url, timeout=1):

    @retry(TimeoutError, tries=3, delay=1, jitter=1, max_delay=3)
    def _check_url():
        return urllib.request.urlopen(url, timeout=timeout).getcode(), None
    try:
        return _check_url()
    except urllib.request.HTTPError as exc:
        return exc.code, str(exc)
    except (TimeoutError, urllib.request.URLError, SocketTimeout) as exc:
        return -1, str(exc)
    except HTTPException as exc:
        return -2, str(exc)

# %%
import shutil


def download_cmakelists(scmurl, dest_filepath, revision):
    scmurl = scmurl.replace("https://github.com/", "").replace("git://github.com/", "").replace(".git", "")
    user, repo = scmurl.split("/")
    cmakelists_url = "https://raw.githubusercontent.com/{user}/{repo}/{revision}/CMakeLists.txt".format(
        user=user,
        repo=repo,
        revision=revision
    )
    if not os.path.exists(dest_filepath):
        try:
            with urllib.request.urlopen(cmakelists_url) as response, open(dest_filepath, 'wb') as out_file:
                shutil.copyfileobj(response, out_file)
        except urllib.request.HTTPError as exc:
            return [(None, "%d, %s" % (exc.code, cmakelists_url),)]
    
    return []

# %%
import urllib.parse


def check_cmakelists(filepath):
    cmakelists_dir = os.path.dirname(filepath)
    cmakelists_filename = os.path.basename(filepath)

    project = ExtensionProject(cmakelists_dir, filename=cmakelists_filename)
    
    urls = []
    errors = []

    def _collect_urls(attribute, required=False, split=False, expect_path=True):
        try:
            cmake_variable_name = "EXTENSION_" + attribute.upper()
            url = project.getValue(cmake_variable_name, substitute=True).strip()
        except KeyError as exc:
            if not required:
                return
            message = str(exc)
            errors.append((attribute, message,))
            return

        if not url:
            if required:
                message = "script sets %r to an empty value" % cmake_variable_name,
                errors.append((attribute, message))
            return

        try:
            result = urllib.parse.urlparse(url)
            if not all([result.scheme, result.netloc, result.path if expect_path else True]):
                raise ValueError("failed to parse either scheme, netloc or path")
        except ValueError:
            message = "script sets %r to an invalid url [%s]" % (cmake_variable_name, url),
            errors.append((attribute, message))
            return

        if split:
            url = re.sub(" +", " ", url)  # Remove redundant spaces
            for item in url.split(" "):
                urls.append((attribute, item,))
        else:
            urls.append((attribute, url,))
    
    _collect_urls("homepage", required=True, expect_path=False)
    _collect_urls("iconurl", required=True)
    _collect_urls("screenshoturls", split=True)

    for attribute, url in urls:
        code, error = check_url(url)
        if code != 200:
            errors.append((attribute, "%d, %s, %s" % (code, url, error),))
    
    return errors

# %%
import urllib.parse
import re


def check_s4ext(metadata):
    urls = []
    errors = []

    def _collect_urls(attribute, required=False, split=False, expect_path=True):
        try:
            url = metadata[attribute]
        except KeyError as exc:
            if not required:
                return
            message = str(exc)
            errors.append((attribute, message,))
            return

        if not url:
            if required:
                message = "s4ext associates %r with an empty value" % attribute,
                errors.append((attribute, message))
            return

        try:
            result = urllib.parse.urlparse(url)
            if not all([result.scheme, result.netloc, result.path if expect_path else True]):
                raise ValueError("failed to parse either scheme, netloc or path")
        except ValueError:
            message = "s4ext associates %r with an invalid url [%s]" % (attribute, url),
            errors.append((attribute, message))
            return

        if split:
            url = re.sub(" +", " ", url)  # Remove redundant spaces
            for item in url.split(" "):
                urls.append((attribute, item,))
        else:
            urls.append((attribute, url,))
    
    _collect_urls("homepage", required=True, expect_path=False)
    _collect_urls("iconurl", required=True)
    _collect_urls("screenshoturls", split=True)

    for attribute, url in urls:
        code, error = check_url(url)
        if code != 200:
            errors.append((attribute, "%d, %s, %s" % (code, url, error),))
    
    return errors

# %%
import glob

s4ext_dir = "/home/jcfr/Projects/ExtensionsIndex"
s4ext_filepaths = glob.glob(os.path.join(s4ext_dir, "*.s4ext"))

print(f"Found {len(s4ext_filepaths)} extension files")
# Out:
# Found 169 extension files

# %%
import urllib.request


# Convenience variable to limit the check to a specific extension
check_extension_names = []

SUPPORTED_CONTEXTS = ["s4ext", "cmakelists"]

def check_extension_metadata(index, filepath, contexts=None, verbose=True):
    
    if not contexts:
        contexts = SUPPORTED_CONTEXTS

    for context in contexts:
        assert context in SUPPORTED_CONTEXTS
    
    extension_name = os.path.splitext(os.path.basename(filepath))[0]

    if check_extension_names and extension_name not in check_extension_names:
        return extension_name, []
    
    def _contextualize(context, values):
       return [(context,) + value for value in values]
        
    def _display(*args, **kwargs):
        if verbose:
            print(*args, **kwargs)

    errors = []

    msg = "[%d/%d] Checking %s ... " % (index + 1, len(s4ext_filepaths), extension_name)
    _display(msg.ljust(50), end='')
    
    metadata = parse_s4ext(filepath)

    if "s4ext" in contexts:
        errors.extend(_contextualize("s4ext", check_s4ext(metadata)))

    scmurl = metadata['scmurl']
    if 'github' not in scmurl:
        _display("[skipping, not a GitHub repository]")
        _display("")
        return extension_name, []

    if "cmakelists" in contexts:
        # Directory to store extension CMakeLists.txt files
        dest_dir = "Extensions-CMakeLists"
        mkdir_p(dest_dir)

        cmakelists_filepath = os.path.join(dest_dir, '%s-CMakeLists.txt' % extension_name)

        # Download CMakeLists.txt
        errors.extend(_contextualize("download_cmakelists", download_cmakelists(scmurl, cmakelists_filepath, metadata['scmrevision'])))

        # Check CMakeLists.txt
        if os.path.exists(cmakelists_filepath):
           errors.extend(_contextualize("cmakelists", check_cmakelists(cmakelists_filepath)))

    if errors:
        _display("[errors]")
        for context, attribute, error in errors:
            if attribute is None:
                _display(f"  {context}, {error}")
            else:
                _display(f"  {context}, {attribute}, {error}")
    else:
        _display("[ok]")

    
    _display("")
    return extension_name, errors

# %%
# for index, filepath in enumerate(s4ext_filepaths[:3]):
#     check_extension_metadata(index, filepath, contexts=["s4ext"])

# %%
from joblib import Parallel, delayed, parallel_backend

with parallel_backend("threading", n_jobs=6):
    jobs = Parallel(verbose=True)(
        delayed(check_extension_metadata)(index, filepath, verbose=False)
        for index, filepath in enumerate(s4ext_filepaths)
    )
# Out:
# [Parallel(n_jobs=6)]: Using backend ThreadingBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=6)]: Done 169 out of 169 | elapsed:  1.5min finished

# %% [markdown]
# ### Issues with URLs found in extensiona's metadata

# %%
for extension_name, errors in sorted(jobs):
    if not errors:
        continue
    print(f"{extension_name}")

    for context, attribute, error in errors:
        if context is None:
            print(f"  {context}, {error}")
        else:
            print(f"  {context}, {attribute}, {error}")
    print("")
# Out:
# AblationPlanner
#   s4ext, homepage, -1, https://github.com/naterex23/SlicerAblationPlanner, <urlopen error timed out>
#   cmakelists, homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/AblationPlanner, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://github.com/naterex23/SlicerAblationPlanner/raw/main/Screenshots/minimum_required_inputs.png,, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://github.com/naterex23/SlicerAblationPlanner/raw/main/Screenshots/minimum_required_placement.png,, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://github.com/naterex23/SlicerAblationPlanner/raw/main/Screenshots/ablation_steps.png,, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://github.com/naterex23/SlicerAblationPlanner/raw/main/Screenshots/ablation_outputs.png,, HTTP Error 404: Not Found
#
# AnomalousFiltersExtension
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/4/40/DTI_FA_raw.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/7/7c/DTI_FA_AAD.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/a/a0/Tractography_AAD.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/4/40/DTI_FA_raw.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/7/7c/DTI_FA_AAD.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/a/a0/Tractography_AAD.png, HTTP Error 404: Not Found
#
# AstmPhantomTest
#   s4ext, homepage, -1, https://www.atracsys-measurement.com/astm/, The read operation timed out
#   cmakelists, homepage, -1, https://www.atracsys-measurement.com/astm/, The read operation timed out
#
# AutomatedDentalTools
#   s4ext, homepage, 'homepage'
#
# BrainVolumeRefinement
#   s4ext, iconurl, 404, https://www.slicer.org/w/images/2/2c/BVeR-logo.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/4/47/T1-FS.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/f/f4/T1-FS-BVeR.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/2/2f/BVeR-3D-Anterior.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/2/29/BVeR-3D-Lateral.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/e/ee/BVeR-3D-FreeView.png, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, https://www.slicer.org/w/images/2/2c/BVeR-logo.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/4/47/T1-FS.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/f/f4/T1-FS-BVeR.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/2/2f/BVeR-3D-Anterior.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/2/29/BVeR-3D-Lateral.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/e/ee/BVeR-3D-FreeView.png, HTTP Error 404: Not Found
#
# BreastImplantAnalyzer
#   s4ext, screenshoturls, -1, https://raw.githubusercontent.com/lancelevine/SlicerBreastImplantAnalyzer/master/Screenshot01.PNG, The read operation timed out
#   cmakelists, homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/BreastImplantAnalyzer, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, http://www.example.com/Slicer/Extensions/BreastImplantAnalyzer.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, http://www.example.com/Slicer/Extensions/BreastImplantAnalyzer/Screenshots/1.png, HTTP Error 404: Not Found
#
# CarreraSlice
#   s4ext, screenshoturls, 404, http://www.na-mic.org/Wiki/images/thumb/d/d0/TendonSegment.png/800px-TendonSegment.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, http://www.na-mic.org/Wiki/images/thumb/b/b8/FiducialSnapshotX.png/800px-FiducialSnapshotX.png, HTTP Error 404: Not Found
#   cmakelists, homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   cmakelists, iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# ChangeTracker
#   s4ext, screenshoturls, -1, http://www.slicer.org/slicerWiki/images/8/8e/Slicer4_ChangeTracker_Ad.png, <urlopen error timed out>
#
# CleverSeg
#   cmakelists, homepage, 404, http://slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/CleverSeg, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, http://www.example.com/Slicer/Extensions/CleverSeg.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, http://www.example.com/Slicer/Extensions/CleverSeg/Screenshots/1.png, HTTP Error 404: Not Found
#
# DRRGenerator
#   s4ext, homepage, 424, https://slicerdrrregistration.000webhostapp.com/drrgenerator, HTTP Error 424:
#   s4ext, iconurl, 424, https://slicerdrrregistration.000webhostapp.com/wp-content/uploads/2020/01/DRRGenerator.png, HTTP Error 424:
#   s4ext, screenshoturls, 424, https://slicerdrrregistration.000webhostapp.com/wp-content/uploads/2020/01/screenshot-1024x556.png, HTTP Error 424:
#   cmakelists, homepage, 404, http://slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/DRRGenerator, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, http://www.example.com/Slicer/Extensions/DRRGenerator.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, http://www.example.com/Slicer/Extensions/DRRGenerator/Screenshots/1.png, HTTP Error 404: Not Found
#
# DatabaseInteractor
#   s4ext, iconurl, 404, https://www.slicer.org/w/images/7/7f/DatabaseInteractor_Logo.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/1/1f/FullView_DatabaseInteractor.png, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, https://www.slicer.org/w/images/7/7f/DatabaseInteractor_Logo.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/1/1f/FullView_DatabaseInteractor.png, HTTP Error 404: Not Found
#
# DiffusionQC
#   s4ext, screenshoturls, 404, https://raw.githubusercontent.com/pnlbwh/SlicerDiffusionQC/master/Misc/DiffusionQC-screenshot.jpg, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://github.com/pnlbwh/SlicerDiffusionQC/raw/master/Misc/DiffusionQC-screenshot.jpg, HTTP Error 404: Not Found
#
# ImageCompare
#   cmakelists, homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/ImageCompare/SyntheticCTEvaluation, HTTP Error 404: Not Found
#
# MONAILabel
#   cmakelists, homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   cmakelists, iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# MarkupsToModel
#   s4ext, homepage, 404, https://github.com/SlicerIGT/MarkupsToModel, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, ("script sets 'EXTENSION_SCREENSHOTURLS' to an invalid url [\\\r\n  https://github.com/SlicerIGT/SlicerMarkupsToModel/raw/master/ClosedSurface.png \\\r\n  https://github.com/SlicerIGT/SlicerMarkupsToModel/raw/master/Curve.png \\]",)
#   cmakelists, homepage, 404, https://github.com/SlicerIGT/MarkupsToModel, HTTP Error 404: Not Found
#
# ModelToModelDistance
#   cmakelists, homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   cmakelists, iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# NvidiaAIAssistedAnnotation
#   s4ext, iconurl, -2, https://raw.githubusercontent.com/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot.jpg https://raw.githubusercontent.com/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot-annotation-points-liver.jpg https://raw.githubusercontent.com/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot-annotation-result-liver.jpg https://raw.githubusercontent.com/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot-segmentation-result-liver.jpg, URL can't contain control characters. '/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot.jpg https://raw.githubusercontent.com/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot-annotation-points-liver.jpg https://raw.githubusercontent.com/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot-annotation-result-liver.jpg https://raw.githubusercontent.com/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot-segmentation-result-liver.jpg' (found at least ' ')
#   s4ext, screenshoturls, 404, https://raw.githubusercontent.com/NVIDIA/ai-assisted-annotation-client/master/slicer-plugin/snapshot.png, HTTP Error 404: Not Found
#   cmakelists, homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   cmakelists, iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# OsteotomyPlanner
#   s4ext, iconurl, 404, https://raw.githubusercontent.com/KitwareMedical/OsteotomyPlanner/master/Planner/Resources/Icons/Planner.png, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, https://raw.githubusercontent.com/KitwareMedical/OsteotomyPlanner/master/Planner/Resources/Icons/Planner.png, HTTP Error 404: Not Found
#
# PBNRR
#   cmakelists, screenshoturls, 404, http://www.example.com/Slicer/Extensions/PBNRR/Screenshots/1.png, HTTP Error 404: Not Found
#
# PETCPhantom
#   s4ext, homepage, 404, http://www.slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/PETCPhantom, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/thumb/0/01/PETCylinderPhantomAnalysisModule.png/800px-PETCylinderPhantomAnalysisModule.png, HTTP Error 404: Not Found
#
# PETDICOMExtension
#   s4ext, screenshoturls, -1, http://wiki.slicer.org/slicerWiki/images/thumb/2/29/DICOM_Browser_RWVM_Plugin.png/800px-DICOM_Browser_RWVM_Plugin.png, <urlopen error timed out>
#
# PathReconstruction
#   cmakelists, homepage, 406, http://www.slicerigt.org, HTTP Error 406: Not Acceptable
#
# PerkTutor
#   s4ext, homepage, 406, http://www.perktutor.org/, HTTP Error 406: Not Acceptable
#
# QuantitativeReporting
#   s4ext, homepage, 403, https://qiicr.gitbooks.io/quantitativereporting-guide, HTTP Error 403: Forbidden
#   cmakelists, homepage, 403, https://qiicr.gitbooks.io/quantitativereporting-guide, HTTP Error 403: Forbidden
#   cmakelists, iconurl, 404, https://www.slicer.org/w/images/3/30/QuantitativeReportingLogo.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/f/fe/QuantitativeReporting-screenshot.jpg, HTTP Error 404: Not Found
#
# RegistrationQA
#   s4ext, iconurl, 404, https://github.com/gsi-biomotion/Slicer-RegQA/blob/master/RegQA/Resources/Icons/RegQAIcon.png, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, https://github.com/gsi-biomotion/SlicerRegistrationQA/blob/master/RegQA/Resources/Icons/RegQAIcon.png, HTTP Error 404: Not Found
#
# ResectionPlanner
#   s4ext, homepage, 404, http://www.slicer.org/slicerWiki/index.php?title=Documentation/Nightly/Extensions/ResectionPlanner, HTTP Error 404: Not Found
#   cmakelists, homepage, 404, http://www.slicer.org/slicerWiki/index.php?title=Documentation/Nightly/Extensions/ResectionPlanner, HTTP Error 404: Not Found
#
# SNRMeasurement
#   s4ext, homepage, 404, http://www.slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/SNRMeasurement, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/a/ab/Slicer-r19441-SNRMeasurement-screenshot.png, HTTP Error 403: Forbidden
#   s4ext, screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/1/1e/Slicer-r19441-SNRMeasurement-screenshot-2.png, HTTP Error 403: Forbidden
#   cmakelists, homepage, 404, http://www.slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/SNRMeasurement, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/a/ab/Slicer-r19441-SNRMeasurement-screenshot.png, HTTP Error 403: Forbidden
#   cmakelists, screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/1/1e/Slicer-r19441-SNRMeasurement-screenshot-2.png, HTTP Error 403: Forbidden
#
# SPHARM-PDM
#   s4ext, iconurl, 404, http://www.na-mic.org/Wiki/images/a/ad/Spharm-pdm-icon.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, http://www.na-mic.org/Wiki/images/3/34/Spharm-pdm-snapshot.png, HTTP Error 404: Not Found
#   cmakelists, homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   cmakelists, iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# Scoliosis
#   download_cmakelists, None, 404, https://raw.githubusercontent.com/SlicerIGT/Scoliosis/master/CMakeLists.txt
#
# SegmentEditorExtraEffects
#   cmakelists, screenshoturls, ("script sets 'EXTENSION_SCREENSHOTURLS' to an invalid url [\\\nhttps://raw.githubusercontent.com/lassoan/SlicerSegmentEditorExtraEffects/master/FastMarchingInput.png \\\nhttps://raw.githubusercontent.com/lassoan/SlicerSegmentEditorExtraEffects/master/FastMarchingOutput.png \\\nhttps://raw.githubusercontent.com/lassoan/SlicerSegmentEditorExtraEffects/master/WatershedOutput.png \\]",)
#
# SegmentRegistration
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/a/a1/20170526_ProstatMRIUSContourPropagation.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/1/15/20160329_MRIUS_1500.gif, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/a/a1/20170526_ProstatMRIUSContourPropagation.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/1/15/20160329_MRIUS_1500.gif, HTTP Error 404: Not Found
#
# ShapePopulationViewer
#   s4ext, screenshoturls, 404, http://wiki.na-mic.org/Wiki/images/8/81/Screenshot1.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, http://wiki.na-mic.org/Wiki/images/1/13/SPVscreenshot2.png, HTTP Error 404: Not Found
#   cmakelists, homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   cmakelists, iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# ShapeRegressionExtension
#   cmakelists, homepage, ("script sets 'EXTENSION_HOMEPAGE' to an empty value",)
#   cmakelists, iconurl, ("script sets 'EXTENSION_ICONURL' to an empty value",)
#
# ShapeVariationAnalyzer
#   s4ext, iconurl, 404, https://www.slicer.org/w/images/3/30/ShapeVariationAnalyzer-Logo.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/f/f0/FullView_ShapeVariationAnalyzer.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/5/57/ShapeVariationAnalyzer-GUI.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/3/30/ShapeVariationAnalyzer-Logo.png, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, https://www.slicer.org/w/images/3/30/ShapeVariationAnalyzer-Logo.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/f/f0/FullView_ShapeVariationAnalyzer.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/5/57/ShapeVariationAnalyzer-GUI.png, HTTP Error 404: Not Found
#
# SkeletalRepresentation
#   cmakelists, iconurl, 404, https://www.slicer.org/w/images/a/a1/SkeletalRepresentation.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/0/08/New_srep.png, HTTP Error 404: Not Found
#
# SkinMouldGenerator
#   s4ext, homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/SkinMouldGenerator, HTTP Error 404: Not Found
#   cmakelists, homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/SkinMouldGenerator, HTTP Error 404: Not Found
#
# SlicerANTs
#   cmakelists, screenshoturls, 404, https://raw.githubusercontent.com/simonoxen/SlicerANTs/master/Documentation/ModuleUI.png, HTTP Error 404: Not Found
#
# SlicerCervicalSpine
#   cmakelists, homepage, 404, http://slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/SlicerCervicalSpine, HTTP Error 404: Not Found
#
# SlicerCochlea
#   cmakelists, homepage, 404, http://slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/SlicerCochlea, HTTP Error 404: Not Found
#
# SlicerFreeSurfer
#   s4ext, screenshoturls, -1, https://github.com/PerkLab/SlicerFreeSurfer/raw/master/Screenshots/FreeSurferImporterInterface.png, The read operation timed out
#
# SlicerIGT
#   s4ext, homepage, 406, http://www.slicerigt.org, HTTP Error 406: Not Acceptable
#   cmakelists, homepage, 406, http://www.slicerigt.org, HTTP Error 406: Not Acceptable
#
# SlicerNetstim
#   cmakelists, homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/SlicerNetstim, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, http://www.example.com/Slicer/Extensions/SlicerNetstim.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, http://www.example.com/Slicer/Extensions/SlicerNetstim/Screenshots/1.png, HTTP Error 404: Not Found
#
# SlicerOpenCV
#   s4ext, homepage, -1, http://slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/SlicerOpenCV, The read operation timed out
#
# SlicerRT
#   s4ext, homepage, 406, http://slicerrt.org, HTTP Error 406: Not Acceptable
#   cmakelists, homepage, 406, http://slicerrt.org, HTTP Error 406: Not Acceptable
#
# SlicerRadiomics
#   s4ext, screenshoturls, 404, http://www.slicer.org/w/images/3/3b/SlicerRadiomics-lung.png, HTTP Error 404: Not Found
#   cmakelists, iconurl, 404, http://www.slicer.org/w/images/6/6b/RadiomicsExtension.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, http://www.slicer.org/w/images/3/3b/SlicerRadiomics-lung.png, HTTP Error 404: Not Found
#
# SlicerRegularizedFastMarching
#   s4ext, iconurl, 404, https://github.com/AldrickF/SlicerRegularizedFastMarching/blob/main/Resources/Icons/RegularizedFastMarching.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://github.com/AldrickF/SlicerRegularizedFastMarching/blob/main/Resources/Icons/SlicerRFM_README_Fig3.png, HTTP Error 404: Not Found
#   cmakelists, homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/RegularizedFastMarching, HTTP Error 404: Not Found
#
# SlicerVMTK
#   s4ext, screenshoturls, -1, http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=228, <urlopen error timed out>
#
# SlicerVirtualReality
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/4/49/SlicerVirtualReality_Screenshot1.png, HTTP Error 404: Not Found
#   s4ext, screenshoturls, 404, https://www.slicer.org/w/images/0/04/SlicerVirtualReality_Screenshot2.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/4/49/SlicerVirtualReality_Screenshot1.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://www.slicer.org/w/images/0/04/SlicerVirtualReality_Screenshot2.png, HTTP Error 404: Not Found
#
# SlicerWMA
#   cmakelists, screenshoturls, 404, http://www.example.com/Slicer/Extensions/SlicerWMA/Screenshots/1.png, HTTP Error 404: Not Found
#
# SoundControl
#   cmakelists, screenshoturls, ("script sets 'EXTENSION_SCREENSHOTURLS' to an invalid url [\\\r\n  https://github.com/SlicerIGT/SlicerSoundControl/raw/master/OpenSoundControl.png \\\r\n  https://github.com/SlicerIGT/SlicerSoundControl/raw/master/SoundNavigation.png \\\r\n  https://github.com/SlicerIGT/SlicerSoundControl/raw/master/PureData.png \\]",)
#
# Stereotaxia
#   cmakelists, homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/Stereotaxia, HTTP Error 404: Not Found
#
# SurfaceMarkup
#   s4ext, screenshoturls, -1, https://github.com/SlicerHeart/SlicerSurfaceMarkup/raw/master/Screenshots/NURBS.png, <urlopen error timed out>
#   cmakelists, screenshoturls, 404, http://www.example.com/Slicer/Extensions/SurfaceMarkup/Screenshots/1.png, HTTP Error 404: Not Found
#
# SurfaceWrapSolidify
#   s4ext, screenshoturls, 404, https://github.com/sebastianandress/Slicer-SurfaceWrapSolidify/raw/master/Resources/Screenshots/screenshot1.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://github.com/sebastianandress/Slicer-SurfaceWrapSolidify/raw/master/Resources/Screenshots/screenshot1.png, HTTP Error 404: Not Found
#
# T2mapping
#   s4ext, homepage, ("s4ext associates 'homepage' with an invalid url [N/a]",)
#
# TCIABrowser
#   s4ext, homepage, 404, http://www.slicer.org/slicerWiki/index.php?title=Documentation/Nightly/Extensions/TCIABrowser, HTTP Error 404: Not Found
#   cmakelists, homepage, 404, http://www.slicer.org/slicerWiki/index.php?title=Documentation/Nightly/Extensions/TCIABrowser, HTTP Error 404: Not Found
#
# TOMAAT
#   cmakelists, screenshoturls, 404, http://www.example.com/Slicer/Extensions/TOMAAT/Screenshots/1.png, HTTP Error 404: Not Found
#
# TorchIO
#   cmakelists, homepage, 404, https://torchio.readthedocs.io/slicer.html, HTTP Error 404: Not Found
#
# ZFrameRegistration
#   s4ext, homepage, 404, http://slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/ZFrameRegistration, HTTP Error 404: Not Found
#
# iGyne
#   s4ext, screenshoturls, 404, https://raw.github.com/gpernelle/iGyne/master/LabelingResult.png, HTTP Error 404: Not Found
#   cmakelists, screenshoturls, 404, https://raw.github.com/gpernelle/iGyne/master/LabelingResult.png, HTTP Error 404: Not Found
