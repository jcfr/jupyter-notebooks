# %%
import sys

# parse_s4ext
extensions_index_script_dir = '/home/jcfr/Projects/SlicerExtensionsIndex/scripts/'
if extensions_index_script_dir not in sys.path:
    sys.path.insert(0, extensions_index_script_dir)

from check_description_files import parse_s4ext

# ExtensionProject
slicer_scripts_dir = "/tmp/SlicerWizard/Utilities/Scripts/"
if slicer_scripts_dir not in sys.path:
    sys.path.insert(0, slicer_scripts_dir)

from SlicerWizard.ExtensionProject import ExtensionProject

# %%
import errno
import os
    
# Copied from https://github.com/scikit-build/scikit-build/blob/master/skbuild/utils/__init__.py
def mkdir_p(path):
    """Ensure directory ``path`` exists. If needed, parent directories
    are created.
    Adapted from http://stackoverflow.com/a/600612/1539918
    """
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:  # pragma: no cover
            raise

# %%
import urllib.request

from socket import timeout as SocketTimeout

def check_url(url, timeout=1):
    try:
        return urllib.request.urlopen(url, timeout=timeout).getcode(), None
    except urllib.request.HTTPError as exc:
        return exc.code, str(exc)
    except (TimeoutError, urllib.request.URLError, SocketTimeout) as exc:
        return -1, str(exc)

# %%
def download_cmakelists(scmurl, dest_filepath):
    scmurl = scmurl.replace("https://github.com/", "").replace("git://github.com/", "").replace(".git", "")
    user, repo = scmurl.split("/")
    cmakelists_url = "https://raw.githubusercontent.com/{user}/{repo}/{revision}/CMakeLists.txt".format(
        user=user,
        repo=repo,
        revision=metadata['scmrevision']
    )
    if not os.path.exists(dest_filepath):
        try:
            with urllib.request.urlopen(cmakelists_url) as response, open(dest_filepath, 'wb') as out_file:
                shutil.copyfileobj(response, out_file)
        except urllib.request.HTTPError as exc:
            return [(None, "%d, %s" % (exc.code, cmakelists_url),)]
    
    return []

# %%
import urllib.parse

def check_cmakelists(filepath):
    cmakelists_dir = os.path.dirname(filepath)
    cmakelists_filename = os.path.basename(filepath)

    project = ExtensionProject(cmakelists_dir, filename=cmakelists_filename)
    
    urls = []
    errors = []

    def _collect_urls(attribute, required=False, split=False):
        try:
            cmake_variable_name = "EXTENSION_" + attribute.upper()
            url = project.getValue(cmake_variable_name, substitute=True).strip()
        except KeyError as exc:
            if not required:
                return
            message = str(exc)
            errors.append((attribute, message,))
            return

        if not url:
            if required:
                message = "script sets %r to an empty value" % cmake_variable_name,
                errors.append((attribute, message))
            return

        try:
            result = urllib.parse.urlparse(url)
            if not all([result.scheme, result.netloc, result.path]):
                raise ValueError("failed to parse either scheme, netloc or path")
        except ValueError:
            message = "script sets %r to an invalid url [%s]" % (cmake_variable_name, url),
            errors.append((attribute, message))
            return

        if split:
            for item in url.split(" "):
                urls.append((attribute, url,))
        else:
            urls.append((attribute, url,))
    
    _collect_urls("homepage", required=True)
    _collect_urls("iconurl", required=True)
    _collect_urls("screenshoturls", split=True)

    for attribute, url in urls:
        code, error = check_url(url)
        if code != 200:
            errors.append((attribute, "%d, %s, %s" % (code, url, error),))
    
    return errors

# %%
import glob
import shutil

import urllib.request

s4ext_dir = "/home/jcfr/Projects/SlicerExtensionsIndex"

s4ext_filepaths = glob.glob(os.path.join(s4ext_dir, "*.s4ext"))

for index, filepath in enumerate(s4ext_filepaths):
    extension_name = os.path.splitext(os.path.basename(filepath))[0]
    
    msg = "[%d/%d] Checking %s ... " % (index + 1, len(s4ext_filepaths), extension_name)
    print(msg.ljust(50), end='')
    
    metadata = parse_s4ext(filepath)
    scmurl = metadata['scmurl']
    
    if 'github' not in scmurl:
        print("[skipping, not a GitHub repository]")
        print("")
        continue
    
    errors = []
    
    # Directory to store extension CMakeLists.txt files
    dest_dir = "Extensions-CMakeLists"
    mkdir_p(dest_dir)
    
    cmakelists_filepath = os.path.join(dest_dir, '%s-CMakeLists.txt' % extension_name)

    # Download CMakeLists.txt
    errors.extend(download_cmakelists(scmurl, cmakelists_filepath))

    # Check CMakeLists.txt
    if os.path.exists(cmakelists_filepath):
       errors.extend(check_cmakelists(cmakelists_filepath))

    if errors:
        print("[errors]")
        for context, error in errors:
            if context is None:
                print("  %s" % error)
            else:
                print("  %s, %s" % (context, error))
        print("")
        continue
    else:
        print("[ok]")

    print("")
# Out:
# [1/182] Checking DiceComputation ...              [ok]
#
# [2/182] Checking QuantitativeReporting ...        [errors]
#   homepage, 403, https://qiicr.gitbooks.io/quantitativereporting-guide, HTTP Error 403: Forbidden
#   iconurl, 404, https://www.slicer.org/w/images/3/30/QuantitativeReportingLogo.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/f/fe/QuantitativeReporting-screenshot.jpg, HTTP Error 404: Not Found
#
# [3/182] Checking CarreraSlice ...                 [errors]
#   homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# [4/182] Checking MFSDA ...                        [errors]
#   screenshoturls, 400, https://raw.githubusercontent.com/DCBIA-OrthoLab/MFSDA_Python/master/MFSDA/Resources/Icons/RunMFSDA.png https://raw.githubusercontent.com/DCBIA-OrthoLab/MFSDA_Python/master/MFSDA/Resources/Icons/SelectVariables.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/DCBIA-OrthoLab/MFSDA_Python/master/MFSDA/Resources/Icons/RunMFSDA.png https://raw.githubusercontent.com/DCBIA-OrthoLab/MFSDA_Python/master/MFSDA/Resources/Icons/SelectVariables.png, HTTP Error 400: Bad Request
#
# [5/182] Checking XNATSlicer ...                   [ok]
#
# [6/182] Checking SlicerDMRI ...                   [errors]
#   homepage, ("script sets 'EXTENSION_HOMEPAGE' to an invalid url [http://slicerdmri.github.io]",)
#
# [7/182] Checking RawImageGuess ...                [errors]
#   screenshoturls, 400, https://github.com/acetylsalicyl/SlicerRawImageGuess/raw/master/Screenshot01.png https://github.com/acetylsalicyl/SlicerRawImageGuess/raw/master/Screenshot02.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://github.com/acetylsalicyl/SlicerRawImageGuess/raw/master/Screenshot01.png https://github.com/acetylsalicyl/SlicerRawImageGuess/raw/master/Screenshot02.png, HTTP Error 400: Bad Request
#
# [8/182] Checking mpReview ...                     [ok]
#
# [9/182] Checking BrainVolumeRefinement ...        [errors]
#   iconurl, 404, https://www.slicer.org/w/images/2/2c/BVeR-logo.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/4/47/T1-FS.png https://www.slicer.org/w/images/f/f4/T1-FS-BVeR.png https://www.slicer.org/w/images/2/2f/BVeR-3D-Anterior.png https://www.slicer.org/w/images/2/29/BVeR-3D-Lateral.png https://www.slicer.org/w/images/e/ee/BVeR-3D-FreeView.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/4/47/T1-FS.png https://www.slicer.org/w/images/f/f4/T1-FS-BVeR.png https://www.slicer.org/w/images/2/2f/BVeR-3D-Anterior.png https://www.slicer.org/w/images/2/29/BVeR-3D-Lateral.png https://www.slicer.org/w/images/e/ee/BVeR-3D-FreeView.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/4/47/T1-FS.png https://www.slicer.org/w/images/f/f4/T1-FS-BVeR.png https://www.slicer.org/w/images/2/2f/BVeR-3D-Anterior.png https://www.slicer.org/w/images/2/29/BVeR-3D-Lateral.png https://www.slicer.org/w/images/e/ee/BVeR-3D-FreeView.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/4/47/T1-FS.png https://www.slicer.org/w/images/f/f4/T1-FS-BVeR.png https://www.slicer.org/w/images/2/2f/BVeR-3D-Anterior.png https://www.slicer.org/w/images/2/29/BVeR-3D-Lateral.png https://www.slicer.org/w/images/e/ee/BVeR-3D-FreeView.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/4/47/T1-FS.png https://www.slicer.org/w/images/f/f4/T1-FS-BVeR.png https://www.slicer.org/w/images/2/2f/BVeR-3D-Anterior.png https://www.slicer.org/w/images/2/29/BVeR-3D-Lateral.png https://www.slicer.org/w/images/e/ee/BVeR-3D-FreeView.png, HTTP Error 404: Not Found
#
# [10/182] Checking MeshToLabelMap ...              [ok]
#
# [11/182] Checking SlicerITKUltrasound ...         [errors]
#   screenshoturls, 400, https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertCurvilinearArray.png https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertPhasedArray3D.png https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertSliceSeries.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertCurvilinearArray.png https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertPhasedArray3D.png https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertSliceSeries.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertCurvilinearArray.png https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertPhasedArray3D.png https://github.com/KitwareMedical/SlicerITKUltrasound/raw/f1f347fc6b9a1a56200ed1bbc2ff7f4e3d0836ef/Documentation/source/Modules/ScanConversion/ScanConvertSliceSeries.png, HTTP Error 400: Bad Request
#
# [12/182] Checking SlicerFreeSurfer ...            [ok]
#
# [13/182] Checking TCIABrowser ...                 [errors]
#   homepage, 404, http://www.slicer.org/slicerWiki/index.php?title=Documentation/Nightly/Extensions/TCIABrowser, HTTP Error 404: Not Found
#
# [14/182] Checking MABMIS ...                      [errors]
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/2/2c/MABMIS_trainning_GUI.png http://wiki.slicer.org/slicerWiki/images/6/64/MABMIS_testing_GUI.png http://wiki.slicer.org/slicerWiki/images/c/c3/MABMIS_algorithm.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/2/2c/MABMIS_trainning_GUI.png http://wiki.slicer.org/slicerWiki/images/6/64/MABMIS_testing_GUI.png http://wiki.slicer.org/slicerWiki/images/c/c3/MABMIS_algorithm.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/2/2c/MABMIS_trainning_GUI.png http://wiki.slicer.org/slicerWiki/images/6/64/MABMIS_testing_GUI.png http://wiki.slicer.org/slicerWiki/images/c/c3/MABMIS_algorithm.png, HTTP Error 404: Not Found
#
# [15/182] Checking PerkTutor ...                   [ok]
#
# [16/182] Checking LAScarSegmenter ...             [ok]
#
# [17/182] Checking LASegmenter ...                 [errors]
#   homepage, 404, http://www.slicer.org/slicerWiki/index.php?title=Documentation/Nightly/Extensions/LASegmenter, HTTP Error 404: Not Found
#
# [18/182] Checking ResectionPlanner ...            [errors]
#   homepage, 404, http://www.slicer.org/slicerWiki/index.php?title=Documentation/Nightly/Extensions/ResectionPlanner, HTTP Error 404: Not Found
#
# [19/182] Checking RSSExtension ...                [errors]
#   iconurl, 404, http://viewvc.slicer.org/viewvc.cgi/Slicer4/trunk/Extensions/Testing/RSSExtension/RSSExtension.png?revision=21746&view=co, HTTP Error 404: Not Found
#
# [20/182] Checking ModelClip ...                   [ok]
#
# [21/182] Checking CornerAnnotation ...            [ok]
#
# [22/182] Checking ModelToModelDistance ...        [errors]
#   homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# [23/182] Checking SlicerCMF ...                   [ok]
#
# [24/182] Checking Slicer-Wasp ...                 [ok]
#
# [25/182] Checking VirtualFractureReconstruction ... [ok]
#
# [26/182] Checking CBC_3D_I2MConversion ...        [errors]
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/e/ea/Brain_before.jpg http://www.slicer.org/slicerWiki/images/b/b4/Brain_after.jpg http://www.slicer.org/slicerWiki/images/f/f3/Brain_after_section.jpg http://www.slicer.org/slicerWiki/images/5/54/Ventricles_before.jpg http://www.slicer.org/slicerWiki/images/3/31/Ventricles_after.jpg http://www.slicer.org/slicerWiki/images/7/7c/Ventricles_after_section.jpg, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/e/ea/Brain_before.jpg http://www.slicer.org/slicerWiki/images/b/b4/Brain_after.jpg http://www.slicer.org/slicerWiki/images/f/f3/Brain_after_section.jpg http://www.slicer.org/slicerWiki/images/5/54/Ventricles_before.jpg http://www.slicer.org/slicerWiki/images/3/31/Ventricles_after.jpg http://www.slicer.org/slicerWiki/images/7/7c/Ventricles_after_section.jpg, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/e/ea/Brain_before.jpg http://www.slicer.org/slicerWiki/images/b/b4/Brain_after.jpg http://www.slicer.org/slicerWiki/images/f/f3/Brain_after_section.jpg http://www.slicer.org/slicerWiki/images/5/54/Ventricles_before.jpg http://www.slicer.org/slicerWiki/images/3/31/Ventricles_after.jpg http://www.slicer.org/slicerWiki/images/7/7c/Ventricles_after_section.jpg, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/e/ea/Brain_before.jpg http://www.slicer.org/slicerWiki/images/b/b4/Brain_after.jpg http://www.slicer.org/slicerWiki/images/f/f3/Brain_after_section.jpg http://www.slicer.org/slicerWiki/images/5/54/Ventricles_before.jpg http://www.slicer.org/slicerWiki/images/3/31/Ventricles_after.jpg http://www.slicer.org/slicerWiki/images/7/7c/Ventricles_after_section.jpg, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/e/ea/Brain_before.jpg http://www.slicer.org/slicerWiki/images/b/b4/Brain_after.jpg http://www.slicer.org/slicerWiki/images/f/f3/Brain_after_section.jpg http://www.slicer.org/slicerWiki/images/5/54/Ventricles_before.jpg http://www.slicer.org/slicerWiki/images/3/31/Ventricles_after.jpg http://www.slicer.org/slicerWiki/images/7/7c/Ventricles_after_section.jpg, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/e/ea/Brain_before.jpg http://www.slicer.org/slicerWiki/images/b/b4/Brain_after.jpg http://www.slicer.org/slicerWiki/images/f/f3/Brain_after_section.jpg http://www.slicer.org/slicerWiki/images/5/54/Ventricles_before.jpg http://www.slicer.org/slicerWiki/images/3/31/Ventricles_after.jpg http://www.slicer.org/slicerWiki/images/7/7c/Ventricles_after_section.jpg, HTTP Error 404: Not Found
# [27/182] Checking SequenceRegistration ...        [errors]
#   screenshoturls, 400, https://raw.githubusercontent.com/moselhy/SlicerSequenceRegistration/master/screenshot01.png https://raw.githubusercontent.com/moselhy/SlicerSequenceRegistration/master/screenshot02.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/moselhy/SlicerSequenceRegistration/master/screenshot01.png https://raw.githubusercontent.com/moselhy/SlicerSequenceRegistration/master/screenshot02.png, HTTP Error 400: Bad Request
#
# [28/182] Checking SlicerRadiomics ...             [errors]
#   iconurl, 404, http://www.slicer.org/w/images/6/6b/RadiomicsExtension.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/w/images/3/3b/SlicerRadiomics-lung.png, HTTP Error 404: Not Found
#
# [29/182] Checking OsteotomyPlanner ...            [errors]
#   iconurl, 404, https://raw.githubusercontent.com/KitwareMedical/OsteotomyPlanner/master/Planner/Resources/Icons/Planner.png, HTTP Error 404: Not Found
#
# [30/182] Checking DTIPrep ...                     [errors]
#   homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# [31/182] Checking SlicerAutoscroll ...            [ok]
#
# [32/182] Checking PathReconstruction ...          [errors]
#   homepage, ("script sets 'EXTENSION_HOMEPAGE' to an invalid url [http://www.slicerigt.org]",)
#
# [33/182] Checking SlicerAstro ...                 [ok]
#
# [34/182] Checking PortPlacement ...               [ok]
#
# [35/182] Checking DebuggingTools ...              [ok]
#
# [36/182] Checking DeveloperToolsForExtensions ... [errors]
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/5/54/SlicerExtension-SlicerDeveloperToolsForExtensions-Screenshot.png http://www.slicer.org/slicerWiki/images/d/db/SlicerExtensions-SlicerDeveloperToolsForExtensions-Screenshot-panels.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/5/54/SlicerExtension-SlicerDeveloperToolsForExtensions-Screenshot.png http://www.slicer.org/slicerWiki/images/d/db/SlicerExtensions-SlicerDeveloperToolsForExtensions-Screenshot-panels.png, HTTP Error 404: Not Found
#
# [37/182] Checking FacetedVisualizer ...           [errors]
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/5/50/ComplexQueryWithImage.jpg http://www.slicer.org/slicerWiki/images/0/00/ComplexQueryAPI.jpg http://www.slicer.org/slicerWiki/images/f/f0/LimbicSystemWithImage.jpg, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/5/50/ComplexQueryWithImage.jpg http://www.slicer.org/slicerWiki/images/0/00/ComplexQueryAPI.jpg http://www.slicer.org/slicerWiki/images/f/f0/LimbicSystemWithImage.jpg, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/5/50/ComplexQueryWithImage.jpg http://www.slicer.org/slicerWiki/images/0/00/ComplexQueryAPI.jpg http://www.slicer.org/slicerWiki/images/f/f0/LimbicSystemWithImage.jpg, HTTP Error 404: Not Found
#
# [38/182] Checking SlicerDevelopmentToolbox ...    [ok]
#
# [39/182] Checking Scoliosis ...                   [errors]
#   404, https://raw.githubusercontent.com/SlicerIGT/Scoliosis/master/CMakeLists.txt
#
# [40/182] Checking SlicerVASST ...                 [ok]
#
# [41/182] Checking SlicerCaseIterator ...          [ok]
#
# [42/182] Checking SlicerRT ...                    [errors]
#   homepage, ("script sets 'EXTENSION_HOMEPAGE' to an invalid url [http://slicerrt.org]",)
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/8/87/SlicerRT_0.10_IsocenterShiftingEvaluation.png http://www.slicer.org/slicerWiki/images/e/ef/SlicerRT_0.11_ProstateLoaded_Beams_ThresholdedDose.png http://www.slicer.org/slicerWiki/images/4/40/SlicerRtFundingSources.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/8/87/SlicerRT_0.10_IsocenterShiftingEvaluation.png http://www.slicer.org/slicerWiki/images/e/ef/SlicerRT_0.11_ProstateLoaded_Beams_ThresholdedDose.png http://www.slicer.org/slicerWiki/images/4/40/SlicerRtFundingSources.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/8/87/SlicerRT_0.10_IsocenterShiftingEvaluation.png http://www.slicer.org/slicerWiki/images/e/ef/SlicerRT_0.11_ProstateLoaded_Beams_ThresholdedDose.png http://www.slicer.org/slicerWiki/images/4/40/SlicerRtFundingSources.png, HTTP Error 404: Not Found
#
# [43/182] Checking ResampleDTIlogEuclidean ...     [errors]
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/4/41/ResampleDTI-Slice_extracted_from_a_real_Diffusion_Tensor_Image_-_No_transformation.png http://www.slicer.org/slicerWiki/images/8/87/ResampleDTI-Real_DTI_transformed_with_a_45deg_rotation_-_Linear_interpolation.png http://www.slicer.org/slicerWiki/images/1/14/ResampleDTI-Real_DTI_upscaled_with_a_factor_2_-_Linear_interpolation.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/4/41/ResampleDTI-Slice_extracted_from_a_real_Diffusion_Tensor_Image_-_No_transformation.png http://www.slicer.org/slicerWiki/images/8/87/ResampleDTI-Real_DTI_transformed_with_a_45deg_rotation_-_Linear_interpolation.png http://www.slicer.org/slicerWiki/images/1/14/ResampleDTI-Real_DTI_upscaled_with_a_factor_2_-_Linear_interpolation.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/4/41/ResampleDTI-Slice_extracted_from_a_real_Diffusion_Tensor_Image_-_No_transformation.png http://www.slicer.org/slicerWiki/images/8/87/ResampleDTI-Real_DTI_transformed_with_a_45deg_rotation_-_Linear_interpolation.png http://www.slicer.org/slicerWiki/images/1/14/ResampleDTI-Real_DTI_upscaled_with_a_factor_2_-_Linear_interpolation.png, HTTP Error 404: Not Found
#
# [44/182] Checking ABC ...                         [errors]
#   homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# [45/182] Checking SlicerDcm2nii ...               [ok]
#
# [46/182] Checking OrthodonticAnalysis ...         [ok]
#
# [47/182] Checking ErodeDilateLabel ...            [ok]
#
# [48/182] Checking SwissSkullStripper ...          [ok]
#
# [49/182] Checking ModelCropper ...                [ok]
#
# [50/182] Checking SlicerAIGT ...                  [ok]
#
# [51/182] Checking MatlabBridge ...                [errors]
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/2/2f/MatlabBridgeScreenshot1.png http://www.slicer.org/slicerWiki/images/1/16/MatlabBridgeScreenshot2.png http://www.slicer.org/slicerWiki/images/b/b9/MatlabBridgeScreenshot3.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/2/2f/MatlabBridgeScreenshot1.png http://www.slicer.org/slicerWiki/images/1/16/MatlabBridgeScreenshot2.png http://www.slicer.org/slicerWiki/images/b/b9/MatlabBridgeScreenshot3.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/2/2f/MatlabBridgeScreenshot1.png http://www.slicer.org/slicerWiki/images/1/16/MatlabBridgeScreenshot2.png http://www.slicer.org/slicerWiki/images/b/b9/MatlabBridgeScreenshot3.png, HTTP Error 404: Not Found
#
# [52/182] Checking SlicerProstateAblation ...      [ok]
#
# [53/182] Checking SlicerCervicalSpine ...         [errors]
#   homepage, 404, http://slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/SlicerCervicalSpine, HTTP Error 404: Not Found
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CS00.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT03.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT04.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CVT05.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST01.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST02.png https://raw.githubusercontent.com/MedicalImageAnalysisTutorials/SlicerCervicalSpine/master/Screenshots/CST03.png, HTTP Error 400: Bad Request
# [54/182] Checking GyroGuide ...                   [ok]
#
# [55/182] Checking PETTumorSegmentation ...        [ok]
#
# [56/182] Checking IASEM ...                       [ok]
#
# [57/182] Checking Auto3dgm ...                    [errors]
#   homepage, ("script sets 'EXTENSION_HOMEPAGE' to an invalid url [https://toothandclaw.github.io]",)
#
# [58/182] Checking ScatteredTransform ...          [ok]
#
# [59/182] Checking MONAILabel ...                  [errors]
#   homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# [60/182] Checking SlicerWMA ...                   [errors]
#   screenshoturls, 404, http://www.example.com/Slicer/Extensions/SlicerWMA/Screenshots/1.png, HTTP Error 404: Not Found
#
# [61/182] Checking SliceTracker ...                [errors]
#   iconurl, 404, https://www.slicer.org/w/images/b/b1/SliceTracker_Logo_1.1_128x128.png, HTTP Error 404: Not Found
#
# [62/182] Checking SNRMeasurement ...              [errors]
#   homepage, 404, http://www.slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/SNRMeasurement, HTTP Error 404: Not Found
#   iconurl, 404, http://viewvc.slicer.org/viewvc.cgi/Slicer4/trunk/Extensions/Testing/SNRMeasurement/SNRMeasurement.png?revision=21745&view=co, HTTP Error 404: Not Found
#   screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/a/ab/Slicer-r19441-SNRMeasurement-screenshot.png http://wiki.slicer.org/slicerWiki/images/1/1e/Slicer-r19441-SNRMeasurement-screenshot-2.png, HTTP Error 403: Forbidden
#   screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/a/ab/Slicer-r19441-SNRMeasurement-screenshot.png http://wiki.slicer.org/slicerWiki/images/1/1e/Slicer-r19441-SNRMeasurement-screenshot-2.png, HTTP Error 403: Forbidden
#
# [63/182] Checking KidneyStoneCalculator ...       [ok]
#
# [64/182] Checking flywheel_connect ...            [ok]
#
# [65/182] Checking SlicerVMTK ...                  [errors]
#   screenshoturls, 400, http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=126 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=227 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=228 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=229, HTTP Error 400: Bad Request
#   screenshoturls, 400, http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=126 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=227 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=228 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=229, HTTP Error 400: Bad Request
#   screenshoturls, 400, http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=126 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=227 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=228 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=229, HTTP Error 400: Bad Request
#   screenshoturls, 400, http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=126 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=227 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=228 http://www.nitrc.org/project/screenshot.php?group_id=196&screenshot_id=229, HTTP Error 400: Bad Request
#
# [66/182] Checking Breast_DCEMRI_FTV ...           [errors]
#   screenshoturls, 400, https://raw.githubusercontent.com/rnadkarni2/SlicerBreast_DCEMRI_FTV/master/Module1Screenshot.png https://raw.githubusercontent.com/rnadkarni2/SlicerBreast_DCEMRI_FTV/master/Module2Screenshot.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/rnadkarni2/SlicerBreast_DCEMRI_FTV/master/Module1Screenshot.png https://raw.githubusercontent.com/rnadkarni2/SlicerBreast_DCEMRI_FTV/master/Module2Screenshot.png, HTTP Error 400: Bad Request
#
# [67/182] Checking SlicerOpenIGTLink ...           [ok]
#
# [68/182] Checking LungCTAnalyzer ...              [errors]
#   screenshoturls, 400, https://user-images.githubusercontent.com/18140094/98554410-f5ddd600-22a0-11eb-9196-b9223c8ada3f.jpg https://user-images.githubusercontent.com/18140094/98554914-9207dd00-22a1-11eb-9bae-7f537a765cc3.jpg https://user-images.githubusercontent.com/18140094/98555178-e6ab5800-22a1-11eb-8cbf-7dfa3e346b43.jpg, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://user-images.githubusercontent.com/18140094/98554410-f5ddd600-22a0-11eb-9196-b9223c8ada3f.jpg https://user-images.githubusercontent.com/18140094/98554914-9207dd00-22a1-11eb-9bae-7f537a765cc3.jpg https://user-images.githubusercontent.com/18140094/98555178-e6ab5800-22a1-11eb-8cbf-7dfa3e346b43.jpg, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://user-images.githubusercontent.com/18140094/98554410-f5ddd600-22a0-11eb-9196-b9223c8ada3f.jpg https://user-images.githubusercontent.com/18140094/98554914-9207dd00-22a1-11eb-9bae-7f537a765cc3.jpg https://user-images.githubusercontent.com/18140094/98555178-e6ab5800-22a1-11eb-8cbf-7dfa3e346b43.jpg, HTTP Error 400: Bad Request
#
# [69/182] Checking OpenCAD ...                     [ok]
#
# [70/182] Checking UKFTractography ...             [errors]
#   homepage, -1, http://www.nitrc.org/plugins/mwiki/index.php/ukftractography:MainPage, The read operation timed out
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/a/ab/Slicer-r19441-CLIExtensionTemplate-screenshot.png http://wiki.slicer.org/slicerWiki/images/1/1e/Slicer-r19441-CLIExtensionTemplate-screenshot-2.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/a/ab/Slicer-r19441-CLIExtensionTemplate-screenshot.png http://wiki.slicer.org/slicerWiki/images/1/1e/Slicer-r19441-CLIExtensionTemplate-screenshot-2.png, HTTP Error 404: Not Found
#
# [71/182] Checking slicerPRISMRendering ...        [ok]
#
# [72/182] Checking SlicerLookingGlass ...          [ok]
#
# [73/182] Checking TOMAAT ...                      [errors]
#   screenshoturls, 404, http://www.example.com/Slicer/Extensions/TOMAAT/Screenshots/1.png, HTTP Error 404: Not Found
#
# [74/182] Checking Cardiac_MRI_Toolkit ...         [errors]
#   homepage, -1, http://capulet.med.utah.edu/namic/cmrslicer/, <urlopen error timed out>
#   iconurl, -1, http://capulet.med.utah.edu/namic/images/CMRTK-logo.png, <urlopen error timed out>
#   screenshoturls, 404, http://wiki.na-mic.org/Wiki/images/d/d1/Carma_afib_inhomogeneity_correction.png http://wiki.na-mic.org/Wiki/images/7/7a/Carma_afib_auto_scar.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://wiki.na-mic.org/Wiki/images/d/d1/Carma_afib_inhomogeneity_correction.png http://wiki.na-mic.org/Wiki/images/7/7a/Carma_afib_auto_scar.png, HTTP Error 404: Not Found
#
# [75/182] Checking iGyne ...                       [errors]
#   screenshoturls, 404, https://raw.github.com/gpernelle/iGyne/master/LabelingResult.png, HTTP Error 404: Not Found
#
# [76/182] Checking NvidiaAIAssistedAnnotation ...  [errors]
#   homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# [77/182] Checking PET-IndiC ...                   [errors]
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/3/32/PET-IndiC_Screenshot1.png http://www.slicer.org/slicerWiki/images/8/8b/PET-IndiC_Screenshot3.png http://www.slicer.org/slicerWiki/images/8/8e/PET-IndiC_Screenshot5.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/3/32/PET-IndiC_Screenshot1.png http://www.slicer.org/slicerWiki/images/8/8b/PET-IndiC_Screenshot3.png http://www.slicer.org/slicerWiki/images/8/8e/PET-IndiC_Screenshot5.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/3/32/PET-IndiC_Screenshot1.png http://www.slicer.org/slicerWiki/images/8/8b/PET-IndiC_Screenshot3.png http://www.slicer.org/slicerWiki/images/8/8e/PET-IndiC_Screenshot5.png, HTTP Error 404: Not Found
#
# [78/182] Checking SlicerHeart ...                 [ok]
#
# [79/182] Checking CurveMaker ...                  [ok]
#
# [80/182] Checking PkModeling ...                  [ok]
#
# [81/182] Checking OpenDose3D ...                  [skipping, not a GitHub repository]
#
# [82/182] Checking DRRGenerator ...                [errors]
#   homepage, 404, http://slicer.org/slicerWiki/index.php/Documentation/Nightly/Extensions/DRRGenerator, HTTP Error 404: Not Found
#   iconurl, 404, http://www.example.com/Slicer/Extensions/DRRGenerator.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.example.com/Slicer/Extensions/DRRGenerator/Screenshots/1.png, HTTP Error 404: Not Found
# [83/182] Checking SegmentationAidedRegistration ... [ok]
#
# [84/182] Checking ChangeTracker ...               [ok]
#
# [85/182] Checking BoneReconstructionPlanner ...   [errors]
#   screenshoturls, 400, https://raw.githubusercontent.com/SlicerIGT/SlicerBoneReconstructionPlanner/main/BoneReconstructionPlanner/Resources/Screenshots/screenshotPlanning.png https://raw.githubusercontent.com/SlicerIGT/SlicerBoneReconstructionPlanner/main/BoneReconstructionPlanner/Resources/Screenshots/screenshotPatientSpecificSurgicalGuides.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/SlicerIGT/SlicerBoneReconstructionPlanner/main/BoneReconstructionPlanner/Resources/Screenshots/screenshotPlanning.png https://raw.githubusercontent.com/SlicerIGT/SlicerBoneReconstructionPlanner/main/BoneReconstructionPlanner/Resources/Screenshots/screenshotPatientSpecificSurgicalGuides.png, HTTP Error 400: Bad Request
#
# [86/182] Checking ZFrameRegistration ...          [errors]
#   screenshoturls, 400, https://raw.githubusercontent.com/SlicerProstate/SlicerZFrameRegistration/master/Screenshots/1.png https://raw.githubusercontent.com/SlicerProstate/SlicerZFrameRegistration/master/Screenshots/2.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/SlicerProstate/SlicerZFrameRegistration/master/Screenshots/1.png https://raw.githubusercontent.com/SlicerProstate/SlicerZFrameRegistration/master/Screenshots/2.png, HTTP Error 400: Bad Request
#
# [87/182] Checking SlicerANTs ...                  [errors]
#   screenshoturls, 404, https://raw.githubusercontent.com/simonoxen/SlicerANTs/master/Documentation/ModuleUI.png, HTTP Error 404: Not Found
#
# [88/182] Checking SlicerMorph ...                 [errors]
#   screenshoturls, 400, https://na-mic.github.io/ProjectWeek/PW30_2019_GranCanaria/Projects/SlicerMorphGeometricMorphometricToolset/SM_screen.png https://na-mic.github.io/ProjectWeek/PW30_2019_GranCanaria/Projects/SlicerMorphGeometricMorphometricToolset/SM2.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://na-mic.github.io/ProjectWeek/PW30_2019_GranCanaria/Projects/SlicerMorphGeometricMorphometricToolset/SM_screen.png https://na-mic.github.io/ProjectWeek/PW30_2019_GranCanaria/Projects/SlicerMorphGeometricMorphometricToolset/SM2.png, HTTP Error 400: Bad Request
#
# [89/182] Checking ShapePopulationViewer ...       [errors]
#   homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# [90/182] Checking SoundControl ...                [errors]
#   screenshoturls, ("script sets 'EXTENSION_SCREENSHOTURLS' to an invalid url [\\\r\n  https://github.com/SlicerIGT/SlicerSoundControl/raw/master/OpenSoundControl.png \\\r\n  https://github.com/SlicerIGT/SlicerSoundControl/raw/master/SoundNavigation.png \\\r\n  https://github.com/SlicerIGT/SlicerSoundControl/raw/master/PureData.png \\]",)
#
# [91/182] Checking DiffusionQC ...                 [errors]
#   screenshoturls, 404, https://github.com/pnlbwh/SlicerDiffusionQC/raw/master/Misc/DiffusionQC-screenshot.jpg, HTTP Error 404: Not Found
#
# [92/182] Checking VolumeClip ...                  [errors]
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/4/4c/VolumeClipScreenshot1.png http://www.slicer.org/slicerWiki/images/5/57/VolumeClipScreenshot2.png http://www.slicer.org/slicerWiki/images/1/1a/VolumeClipScreenshot3.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/4/4c/VolumeClipScreenshot1.png http://www.slicer.org/slicerWiki/images/5/57/VolumeClipScreenshot2.png http://www.slicer.org/slicerWiki/images/1/1a/VolumeClipScreenshot3.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.slicer.org/slicerWiki/images/4/4c/VolumeClipScreenshot1.png http://www.slicer.org/slicerWiki/images/5/57/VolumeClipScreenshot2.png http://www.slicer.org/slicerWiki/images/1/1a/VolumeClipScreenshot3.png, HTTP Error 404: Not Found
#
# [93/182] Checking SlicerProstate ...              [errors]
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/f/ff/DistanceMapBasedRegistration_example1.png http://wiki.slicer.org/slicerWiki/images/3/36/SegmentationSmoothing_example1.png http://wiki.slicer.org/slicerWiki/images/c/c3/QuadEdgeSurfaceMesher_example1.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/f/ff/DistanceMapBasedRegistration_example1.png http://wiki.slicer.org/slicerWiki/images/3/36/SegmentationSmoothing_example1.png http://wiki.slicer.org/slicerWiki/images/c/c3/QuadEdgeSurfaceMesher_example1.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/f/ff/DistanceMapBasedRegistration_example1.png http://wiki.slicer.org/slicerWiki/images/3/36/SegmentationSmoothing_example1.png http://wiki.slicer.org/slicerWiki/images/c/c3/QuadEdgeSurfaceMesher_example1.png, HTTP Error 404: Not Found
#
# [94/182] Checking FiducialsToModelDistance ...    [errors]
#   screenshoturls, 400, https://raw.githubusercontent.com/ReynoldsJ20/SlicerFiducialsToModelDistance/master/Screenshots/ScreenShot1.PNG https://raw.githubusercontent.com/ReynoldsJ20/SlicerFiducialsToModelDistance/master/Screenshots/ScreenShot2.PNG, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/ReynoldsJ20/SlicerFiducialsToModelDistance/master/Screenshots/ScreenShot1.PNG https://raw.githubusercontent.com/ReynoldsJ20/SlicerFiducialsToModelDistance/master/Screenshots/ScreenShot2.PNG, HTTP Error 400: Bad Request
#
# [95/182] Checking exStone ...                     [errors]
#   iconurl, 404, https://www.slicer.org/w/images/e/e7/Urinary_calculi.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/6/6b/Extract_parameters_in_any_angle_.gif, HTTP Error 404: Not Found
#
# [96/182] Checking NeedleFinder ...                [ok]
#
# [97/182] Checking SegmentMesher ...               [ok]
#
# [98/182] Checking BreastImplantAnalyzer ...       [errors]
#   homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/BreastImplantAnalyzer, HTTP Error 404: Not Found
#   iconurl, 404, http://www.example.com/Slicer/Extensions/BreastImplantAnalyzer.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://www.example.com/Slicer/Extensions/BreastImplantAnalyzer/Screenshots/1.png, HTTP Error 404: Not Found
#
# [99/182] Checking SlicerIMSTK ...                 [skipping, not a GitHub repository]
#
# [100/182] Checking BoneTextureExtension ...       [ok]
#
# [101/182] Checking SegmentRegistration ...        [errors]
#   screenshoturls, 404, https://www.slicer.org/w/images/a/a1/20170526_ProstatMRIUSContourPropagation.png https://www.slicer.org/w/images/1/15/20160329_MRIUS_1500.gif, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/a/a1/20170526_ProstatMRIUSContourPropagation.png https://www.slicer.org/w/images/1/15/20160329_MRIUS_1500.gif, HTTP Error 404: Not Found
#
# [102/182] Checking PercutaneousApproachAnalysis ... [ok]
#
# [103/182] Checking TITAN ...                      [ok]
#
# [104/182] Checking ROBEXBrainExtraction ...       [errors]
#   iconurl, 404, https://www.slicer.org/w/images/7/7a/ROBEXBrainExtraction-logo.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/c/ca/AllHeadMRI.png https://www.slicer.org/w/images/0/06/BrainMRI.png https://www.slicer.org/w/images/7/71/ROBEXBrainExtraction-GUI.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/c/ca/AllHeadMRI.png https://www.slicer.org/w/images/0/06/BrainMRI.png https://www.slicer.org/w/images/7/71/ROBEXBrainExtraction-GUI.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/c/ca/AllHeadMRI.png https://www.slicer.org/w/images/0/06/BrainMRI.png https://www.slicer.org/w/images/7/71/ROBEXBrainExtraction-GUI.png, HTTP Error 404: Not Found
#
# [105/182] Checking SlicerPinholeCameras ...       [ok]
#
# [106/182] Checking ShapeQuantifier ...            [errors]
#   screenshoturls, 400, https://raw.githubusercontent.com/DCBIA-OrthoLab/AnglePlanes-Extension/master/AnglePlanes.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/EasyClip-Extension/master/EasyClip.png, http://https://raw.githubusercontent.com/DCBIA-OrthoLab/MeshStatisticsExtension/master/MeshStatistics/Resources/Icons/MeshStatistics.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/PickAndPaintExtension/master/PickAndPaint/Resources/Icons/PickAndPaint.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/Q3DCExtension/master/Q3DC.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/DCBIA-OrthoLab/AnglePlanes-Extension/master/AnglePlanes.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/EasyClip-Extension/master/EasyClip.png, http://https://raw.githubusercontent.com/DCBIA-OrthoLab/MeshStatisticsExtension/master/MeshStatistics/Resources/Icons/MeshStatistics.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/PickAndPaintExtension/master/PickAndPaint/Resources/Icons/PickAndPaint.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/Q3DCExtension/master/Q3DC.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/DCBIA-OrthoLab/AnglePlanes-Extension/master/AnglePlanes.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/EasyClip-Extension/master/EasyClip.png, http://https://raw.githubusercontent.com/DCBIA-OrthoLab/MeshStatisticsExtension/master/MeshStatistics/Resources/Icons/MeshStatistics.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/PickAndPaintExtension/master/PickAndPaint/Resources/Icons/PickAndPaint.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/Q3DCExtension/master/Q3DC.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/DCBIA-OrthoLab/AnglePlanes-Extension/master/AnglePlanes.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/EasyClip-Extension/master/EasyClip.png, http://https://raw.githubusercontent.com/DCBIA-OrthoLab/MeshStatisticsExtension/master/MeshStatistics/Resources/Icons/MeshStatistics.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/PickAndPaintExtension/master/PickAndPaint/Resources/Icons/PickAndPaint.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/Q3DCExtension/master/Q3DC.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/DCBIA-OrthoLab/AnglePlanes-Extension/master/AnglePlanes.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/EasyClip-Extension/master/EasyClip.png, http://https://raw.githubusercontent.com/DCBIA-OrthoLab/MeshStatisticsExtension/master/MeshStatistics/Resources/Icons/MeshStatistics.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/PickAndPaintExtension/master/PickAndPaint/Resources/Icons/PickAndPaint.png, https://raw.githubusercontent.com/DCBIA-OrthoLab/Q3DCExtension/master/Q3DC.png, HTTP Error 400: Bad Request
# [107/182] Checking GelDosimetryAnalysis ...       [errors]
#   screenshoturls, 404, https://www.slicer.org/slicerWiki/images/8/80/20150605_Gamma_98percent.png https://www.slicer.org/slicerWiki/images/9/96/GelDosimetry_Step3a_OpticalCtMeasuredDose.png http://www.slicer.org/slicerWiki/images/6/68/GelDosimetrySlicelet_0.1_CalibrationCurvesAligned.png http://www.slicer.org/slicerWiki/images/5/51/GelDosimetrySlicelet_0.1_OdVsDoseCurve.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/slicerWiki/images/8/80/20150605_Gamma_98percent.png https://www.slicer.org/slicerWiki/images/9/96/GelDosimetry_Step3a_OpticalCtMeasuredDose.png http://www.slicer.org/slicerWiki/images/6/68/GelDosimetrySlicelet_0.1_CalibrationCurvesAligned.png http://www.slicer.org/slicerWiki/images/5/51/GelDosimetrySlicelet_0.1_OdVsDoseCurve.png, HTTP Error 404: Not Found
# ...
#   homepage, 404, http://www.slicer.org/slicerWiki/index.php?title=Documentation/Nightly/Extensions/DeepInfer, HTTP Error 404: Not Found
#   iconurl, 404, https://www.slicer.org/w/images/a/a9/Deepinfer-256.png, HTTP Error 404: Not Found
#
# [152/182] Checking SlicerVirtualReality ...       [errors]
#   screenshoturls, 404, https://www.slicer.org/w/images/4/49/SlicerVirtualReality_Screenshot1.png https://www.slicer.org/w/images/0/04/SlicerVirtualReality_Screenshot2.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/4/49/SlicerVirtualReality_Screenshot1.png https://www.slicer.org/w/images/0/04/SlicerVirtualReality_Screenshot2.png, HTTP Error 404: Not Found
#
# [153/182] Checking PETLiverUptakeMeasurement ...  [ok]
#
# [154/182] Checking PyTorch ...                    [ok]
#
# [155/182] Checking LightWeightRobotIGT ...        [errors]
#   screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/4/42/Slicer-r19441-LightWeightRobotIGT-screenshot.png, HTTP Error 403: Forbidden
#
# [156/182] Checking SkullStripper ...              [errors]
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/a/ab/Slicer-r19441-CLIExtensionTemplate-screenshot.png http://wiki.slicer.org/slicerWiki/images/1/1e/Slicer-r19441-CLIExtensionTemplate-screenshot-2.png, HTTP Error 404: Not Found
#   screenshoturls, 404, http://wiki.slicer.org/slicerWiki/images/a/ab/Slicer-r19441-CLIExtensionTemplate-screenshot.png http://wiki.slicer.org/slicerWiki/images/1/1e/Slicer-r19441-CLIExtensionTemplate-screenshot-2.png, HTTP Error 404: Not Found
#
# [157/182] Checking lapdMouseBrowser ...           [errors]
#   screenshoturls, 404, https://www.slicer.org/w/images/b/b2/LapdMouseDBBrowserWindow.png https://www.slicer.org/w/images/6/67/LapdMouseStandardFiles.png https://www.slicer.org/w/images/e/ed/LapdMouseNearAciniTree.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/b/b2/LapdMouseDBBrowserWindow.png https://www.slicer.org/w/images/6/67/LapdMouseStandardFiles.png https://www.slicer.org/w/images/e/ed/LapdMouseNearAciniTree.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/b/b2/LapdMouseDBBrowserWindow.png https://www.slicer.org/w/images/6/67/LapdMouseStandardFiles.png https://www.slicer.org/w/images/e/ed/LapdMouseNearAciniTree.png, HTTP Error 404: Not Found
#
# [158/182] Checking PETDICOMExtension ...          [errors]
#   screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/thumb/2/2e/SUV_Factor_Calculator_GUI.png/418px-SUV_Factor_Calculator_GUI.png http://wiki.slicer.org/slicerWiki/images/thumb/2/29/DICOM_Browser_RWVM_Plugin.png/800px-DICOM_Browser_RWVM_Plugin.png http://wiki.slicer.org/slicerWiki/images/thumb/4/43/DICOM_Browser_PET_SUV_Plugin.png/800px-DICOM_Browser_PET_SUV_Plugin.png, HTTP Error 403: Forbidden
#   screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/thumb/2/2e/SUV_Factor_Calculator_GUI.png/418px-SUV_Factor_Calculator_GUI.png http://wiki.slicer.org/slicerWiki/images/thumb/2/29/DICOM_Browser_RWVM_Plugin.png/800px-DICOM_Browser_RWVM_Plugin.png http://wiki.slicer.org/slicerWiki/images/thumb/4/43/DICOM_Browser_PET_SUV_Plugin.png/800px-DICOM_Browser_PET_SUV_Plugin.png, HTTP Error 403: Forbidden
#   screenshoturls, 403, http://wiki.slicer.org/slicerWiki/images/thumb/2/2e/SUV_Factor_Calculator_GUI.png/418px-SUV_Factor_Calculator_GUI.png http://wiki.slicer.org/slicerWiki/images/thumb/2/29/DICOM_Browser_RWVM_Plugin.png/800px-DICOM_Browser_RWVM_Plugin.png http://wiki.slicer.org/slicerWiki/images/thumb/4/43/DICOM_Browser_PET_SUV_Plugin.png/800px-DICOM_Browser_PET_SUV_Plugin.png, HTTP Error 403: Forbidden
#
# [159/182] Checking SlicerIGT ...                  [errors]
#   homepage, ("script sets 'EXTENSION_HOMEPAGE' to an invalid url [http://www.slicerigt.org]",)
#
# [160/182] Checking SupervisedSegmentationToolbox ... [errors]
#   screenshoturls, 400, https://docs.google.com/uc?id=1Jegr46jIRPKddDwwUETp6WFJgYwmxrEF https://docs.google.com/uc?id=1SotrSf_XJY1gZmPrl9Ln6E5eb0wwYEaO, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://docs.google.com/uc?id=1Jegr46jIRPKddDwwUETp6WFJgYwmxrEF https://docs.google.com/uc?id=1SotrSf_XJY1gZmPrl9Ln6E5eb0wwYEaO, HTTP Error 400: Bad Request
# [161/182] Checking EasyClip ...                   [ok]
#
# [162/182] Checking DSCMRIAnalysis ...             [ok]
#
# [163/182] Checking Slicer-AirwaySegmentation ...  [ok]
#
# [164/182] Checking LongitudinalPETCT ...          [ok]
#
# [165/182] Checking SegmentEditorExtraEffects ...  [errors]
#   screenshoturls, ("script sets 'EXTENSION_SCREENSHOTURLS' to an invalid url [\\\nhttps://raw.githubusercontent.com/lassoan/SlicerSegmentEditorExtraEffects/master/FastMarchingInput.png \\\nhttps://raw.githubusercontent.com/lassoan/SlicerSegmentEditorExtraEffects/master/FastMarchingOutput.png \\\nhttps://raw.githubusercontent.com/lassoan/SlicerSegmentEditorExtraEffects/master/WatershedOutput.png \\]",)
#
# [166/182] Checking ImageCompare ...               [errors]
#   homepage, 404, https://www.slicer.org/wiki/Documentation/Nightly/Extensions/ImageCompare/SyntheticCTEvaluation, HTTP Error 404: Not Found
#
# [167/182] Checking OpenCVExample ...              [ok]
#
# [168/182] Checking T2mapping ...                  [errors]
#   screenshoturls, 400, https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/1_Module_and_multi_echo_t2_image.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/2_Module_create_new_volume_t2.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/3_Example_resulting_t2_map_r2_threshold_0.7_t2_upper_threshold_100.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/4_Example_resulting_R2_map_r2_threshold_0.7_t2_upper_threshold_100.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/1_Module_and_multi_echo_t2_image.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/2_Module_create_new_volume_t2.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/3_Example_resulting_t2_map_r2_threshold_0.7_t2_upper_threshold_100.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/4_Example_resulting_R2_map_r2_threshold_0.7_t2_upper_threshold_100.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/1_Module_and_multi_echo_t2_image.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/2_Module_create_new_volume_t2.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/3_Example_resulting_t2_map_r2_threshold_0.7_t2_upper_threshold_100.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/4_Example_resulting_R2_map_r2_threshold_0.7_t2_upper_threshold_100.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/1_Module_and_multi_echo_t2_image.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/2_Module_create_new_volume_t2.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/3_Example_resulting_t2_map_r2_threshold_0.7_t2_upper_threshold_100.png https://raw.githubusercontent.com/gattia/Slicer-T2mapping/master/Screenshots/4_Example_resulting_R2_map_r2_threshold_0.7_t2_upper_threshold_100.png, HTTP Error 400: Bad Request
#
# [169/182] Checking BoneThicknessMapping ...       [errors]
#   screenshoturls, 400, https://github.com/Auditory-Biophysics-Lab/SlicerBoneThicknessMappingExtension/blob/master/Images/general_screenshot.png https://github.com/Auditory-Biophysics-Lab/SlicerBoneThicknessMappingExtension/blob/master/Images/complete.png, HTTP Error 400: Bad Request
#   screenshoturls, 400, https://github.com/Auditory-Biophysics-Lab/SlicerBoneThicknessMappingExtension/blob/master/Images/general_screenshot.png https://github.com/Auditory-Biophysics-Lab/SlicerBoneThicknessMappingExtension/blob/master/Images/complete.png, HTTP Error 400: Bad Request
#
# [170/182] Checking MarkupsToModel ...             [errors]
#   screenshoturls, ("script sets 'EXTENSION_SCREENSHOTURLS' to an invalid url [\\\r\n  https://github.com/SlicerIGT/SlicerMarkupsToModel/raw/master/ClosedSurface.png \\\r\n  https://github.com/SlicerIGT/SlicerMarkupsToModel/raw/master/Curve.png \\]",)
#   homepage, 404, https://github.com/SlicerIGT/MarkupsToModel, HTTP Error 404: Not Found
#
# [171/182] Checking ShapeVariationAnalyzer ...     [errors]
#   iconurl, 404, https://www.slicer.org/w/images/3/30/ShapeVariationAnalyzer-Logo.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/f/f0/FullView_ShapeVariationAnalyzer.png https://www.slicer.org/w/images/5/57/ShapeVariationAnalyzer-GUI.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/f/f0/FullView_ShapeVariationAnalyzer.png https://www.slicer.org/w/images/5/57/ShapeVariationAnalyzer-GUI.png, HTTP Error 404: Not Found
#
# [172/182] Checking ArduinoController ...          [ok]
#
# [173/182] Checking IntensitySegmenter ...         [ok]
#
# [174/182] Checking Eigen3 ...                     [errors]
#   homepage, "script does not set 'EXTENSION_HOMEPAGE'"
#   iconurl, "script does not set 'EXTENSION_ICONURL'"
#
# [175/182] Checking VASSTAlgorithms ...            [ok]
#
# [176/182] Checking LesionSimulator ...            [errors]
#   iconurl, 404, https://www.slicer.org/w/images/d/d5/LesionSimulator-logo.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/5/55/LesionLoad_2mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_5mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_40mL.png https://www.slicer.org/w/images/f/f0/3DLesionsOverlay.png https://www.slicer.org/w/images/1/1a/MNI152_orig.png https://www.slicer.org/w/images/e/ef/MNI152_lesionload40mL.png https://www.slicer.org/w/images/c/c9/MNI152_orig_sag.png https://www.slicer.org/w/images/a/aa/MNI152_lesionload40mL_sag.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/5/55/LesionLoad_2mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_5mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_40mL.png https://www.slicer.org/w/images/f/f0/3DLesionsOverlay.png https://www.slicer.org/w/images/1/1a/MNI152_orig.png https://www.slicer.org/w/images/e/ef/MNI152_lesionload40mL.png https://www.slicer.org/w/images/c/c9/MNI152_orig_sag.png https://www.slicer.org/w/images/a/aa/MNI152_lesionload40mL_sag.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/5/55/LesionLoad_2mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_5mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_40mL.png https://www.slicer.org/w/images/f/f0/3DLesionsOverlay.png https://www.slicer.org/w/images/1/1a/MNI152_orig.png https://www.slicer.org/w/images/e/ef/MNI152_lesionload40mL.png https://www.slicer.org/w/images/c/c9/MNI152_orig_sag.png https://www.slicer.org/w/images/a/aa/MNI152_lesionload40mL_sag.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/5/55/LesionLoad_2mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_5mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_40mL.png https://www.slicer.org/w/images/f/f0/3DLesionsOverlay.png https://www.slicer.org/w/images/1/1a/MNI152_orig.png https://www.slicer.org/w/images/e/ef/MNI152_lesionload40mL.png https://www.slicer.org/w/images/c/c9/MNI152_orig_sag.png https://www.slicer.org/w/images/a/aa/MNI152_lesionload40mL_sag.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/5/55/LesionLoad_2mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_5mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_40mL.png https://www.slicer.org/w/images/f/f0/3DLesionsOverlay.png https://www.slicer.org/w/images/1/1a/MNI152_orig.png https://www.slicer.org/w/images/e/ef/MNI152_lesionload40mL.png https://www.slicer.org/w/images/c/c9/MNI152_orig_sag.png https://www.slicer.org/w/images/a/aa/MNI152_lesionload40mL_sag.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/5/55/LesionLoad_2mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_5mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_40mL.png https://www.slicer.org/w/images/f/f0/3DLesionsOverlay.png https://www.slicer.org/w/images/1/1a/MNI152_orig.png https://www.slicer.org/w/images/e/ef/MNI152_lesionload40mL.png https://www.slicer.org/w/images/c/c9/MNI152_orig_sag.png https://www.slicer.org/w/images/a/aa/MNI152_lesionload40mL_sag.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/5/55/LesionLoad_2mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_5mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_40mL.png https://www.slicer.org/w/images/f/f0/3DLesionsOverlay.png https://www.slicer.org/w/images/1/1a/MNI152_orig.png https://www.slicer.org/w/images/e/ef/MNI152_lesionload40mL.png https://www.slicer.org/w/images/c/c9/MNI152_orig_sag.png https://www.slicer.org/w/images/a/aa/MNI152_lesionload40mL_sag.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/w/images/5/55/LesionLoad_2mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_5mL.png https://www.slicer.org/w/images/f/f5/LesionLoad_40mL.png https://www.slicer.org/w/images/f/f0/3DLesionsOverlay.png https://www.slicer.org/w/images/1/1a/MNI152_orig.png https://www.slicer.org/w/images/e/ef/MNI152_lesionload40mL.png https://www.slicer.org/w/images/c/c9/MNI152_orig_sag.png https://www.slicer.org/w/images/a/aa/MNI152_lesionload40mL_sag.png, HTTP Error 404: Not Found
# [177/182] Checking SegmentationWizard ...         [ok]
#
# [178/182] Checking FilmDosimetryAnalysis ...      [errors]
#   screenshoturls, 404, https://www.slicer.org/slicerWiki/images/8/8c/FilmDosimetry_1.0_Gamma.png https://www.slicer.org/slicerWiki/images/7/72/FilmDosimetry_1.0_Registration.png https://www.slicer.org/slicerWiki/images/4/4c/FilmDosimetry_1.0_CalibrationFunction.png https://www.slicer.org/slicerWiki/images/d/d8/FilmDosimetry_1.0_CalibrationBatch.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/slicerWiki/images/8/8c/FilmDosimetry_1.0_Gamma.png https://www.slicer.org/slicerWiki/images/7/72/FilmDosimetry_1.0_Registration.png https://www.slicer.org/slicerWiki/images/4/4c/FilmDosimetry_1.0_CalibrationFunction.png https://www.slicer.org/slicerWiki/images/d/d8/FilmDosimetry_1.0_CalibrationBatch.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/slicerWiki/images/8/8c/FilmDosimetry_1.0_Gamma.png https://www.slicer.org/slicerWiki/images/7/72/FilmDosimetry_1.0_Registration.png https://www.slicer.org/slicerWiki/images/4/4c/FilmDosimetry_1.0_CalibrationFunction.png https://www.slicer.org/slicerWiki/images/d/d8/FilmDosimetry_1.0_CalibrationBatch.png, HTTP Error 404: Not Found
#   screenshoturls, 404, https://www.slicer.org/slicerWiki/images/8/8c/FilmDosimetry_1.0_Gamma.png https://www.slicer.org/slicerWiki/images/7/72/FilmDosimetry_1.0_Registration.png https://www.slicer.org/slicerWiki/images/4/4c/FilmDosimetry_1.0_CalibrationFunction.png https://www.slicer.org/slicerWiki/images/d/d8/FilmDosimetry_1.0_CalibrationBatch.png, HTTP Error 404: Not Found
#
# [179/182] Checking SurfaceWrapSolidify ...        [errors]
#   screenshoturls, 404, https://github.com/sebastianandress/Slicer-SurfaceWrapSolidify/raw/master/Resources/Screenshots/screenshot1.png, HTTP Error 404: Not Found
#
# [180/182] Checking ShapeRegressionExtension ...   [errors]
#   homepage, ("script sets 'EXTENSION_HOMEPAGE' to an empty value",)
#   iconurl, ("script sets 'EXTENSION_ICONURL' to an empty value",)
#
# [181/182] Checking SlicerOpenAnatomy ...          [ok]
#
# [182/182] Checking SlicerIGSIO ...                [ok]
